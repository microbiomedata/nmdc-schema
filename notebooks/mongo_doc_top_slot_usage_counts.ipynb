# %%
import os
import csv

# import pandas as pd
from dotenv import load_dotenv
from linkml_runtime import SchemaView
from linkml_runtime.linkml_model.meta import ClassDefinition
from pymongo import MongoClient

# %%
mongo_db_name = "nmdc"
output_file = '../local/populated_slot_counts.tsv'
dot_env_file = "../local/.env"
schema_file = "../src/schema/nmdc.yaml"

# %%
nmdc_view = SchemaView(schema_file)

# %%
load_dotenv(dot_env_file)
# Out:
# True

# %%
mongo_pw = os.getenv('SOURCE_MONGO_PASS')
# print(mongo_pw)
mongo_user = os.getenv('SOURCE_MONGO_USER')
print(mongo_user)
# Out:
# mam

# %%
Database = nmdc_view.get_class('Database')

# %%
def get_collection_names(mongo_db):
    collections = mongo_db.list_collection_names()
    return list(collections)

# %%
def get_synonymous_collection_db_slots(mongo_db, schema_view: SchemaView, class_name='Database'):
    class_slots = schema_view.class_induced_slots(class_name)
    class_slot_names = [s.name for s in class_slots]
    class_slot_names.sort()

    collections = get_collection_names(mongo_db)

    synonymous_collection_names = set_arithmetic(set(class_slot_names), set(collections))

    return synonymous_collection_names

# %%
def set_arithmetic(set1, set2):
    set1_only = set1 - set2
    set2_only = set2 - set1
    intersection = set1.intersection(set2)
    temp = {
        'set 1 only': set1_only,
        'set 2 only': set2_only,
        'intersection': intersection
    }
    return temp

# %%
def check_collection_for_populated_slot(mongo_db, collection_name, selected_slot):
    collection = mongo_db[collection_name]

    query = {selected_slot: {'$exists': True}}
    # result = collection.find(query)

    result = collection.count_documents(query)

    return result

# %%
def write_dicts_to_tsv(data, filename):
    fieldnames = data[0].keys()  # Assume all dictionaries have the same keys

    with open(filename, 'w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames, delimiter='\t')
        writer.writeheader()
        writer.writerows(data)

# %%
client = MongoClient("localhost",
                     port=27777,
                     username=mongo_user,
                     password=mongo_pw,
                     authSource="admin",
                     authMechanism='SCRAM-SHA-256',  # todo should be an option
                     directConnection=True
                     )

# %%
db = client[mongo_db_name]

# %%
collections_to_check = get_synonymous_collection_db_slots(db, nmdc_view, 'Database')
# pprint.pprint(collections_to_check)

# %%
populated_slot_counts = []
for slot_name in collections_to_check['intersection']:
    slots_range = nmdc_view.get_slot(slot_name).range
    if slots_range:
        range_element = nmdc_view.get_element(slots_range)
        range_type = type(range_element)
        if range_type == ClassDefinition:
            range_slots = nmdc_view.class_induced_slots(slots_range)
            for range_slot in range_slots:
                # print(f"checking {slot_name} {range_slot.name}")
                doc_count = check_collection_for_populated_slot(db, slot_name, range_slot.name)
                print(f"{slot_name} {range_slot.name} doc_count: {doc_count}")
                population_dict = {
                    'collection': slot_name,
                    'slot': range_slot.name,
                    'doc_count': doc_count
                }
                populated_slot_counts.append(population_dict)
# Out:
# collecting_biosamples_from_site_set has_input doc_count: 0
# collecting_biosamples_from_site_set has_output doc_count: 0
# collecting_biosamples_from_site_set protocol_link doc_count: 0
# collecting_biosamples_from_site_set start_date doc_count: 0
# collecting_biosamples_from_site_set end_date doc_count: 0
# collecting_biosamples_from_site_set id doc_count: 0
# collecting_biosamples_from_site_set name doc_count: 0
# collecting_biosamples_from_site_set description doc_count: 0
# collecting_biosamples_from_site_set alternative_identifiers doc_count: 0
# study_set emsl_project_dois doc_count: 0
# study_set neon_study_identifiers doc_count: 0
# study_set id doc_count: 14
# study_set alternative_identifiers doc_count: 0
# study_set gnps_task_identifiers doc_count: 0
# study_set abstract doc_count: 0
# study_set alternative_descriptions doc_count: 0
# study_set alternative_names doc_count: 0
# study_set alternative_titles doc_count: 0
# study_set doi doc_count: 12
# study_set ecosystem doc_count: 8
# study_set ecosystem_category doc_count: 8
# study_set ecosystem_subtype doc_count: 8
# study_set ecosystem_type doc_count: 8
# study_set ess_dive_datasets doc_count: 2
# study_set funding_sources doc_count: 12
# study_set gold_study_identifiers doc_count: 14
# study_set has_credit_associations doc_count: 12
# study_set insdc_bioproject_identifiers doc_count: 0
# study_set massive_study_identifiers doc_count: 1
# study_set mgnify_project_identifiers doc_count: 0
# study_set notes doc_count: 0
# study_set objective doc_count: 0
# study_set principal_investigator doc_count: 14
# study_set publications doc_count: 6
# study_set related_identifiers doc_count: 0
# study_set relevant_protocols doc_count: 2
# study_set specific_ecosystem doc_count: 8
# study_set study_image doc_count: 3
# study_set title doc_count: 10
# study_set type doc_count: 13
# study_set websites doc_count: 10
# study_set name doc_count: 13
# study_set description doc_count: 14
# metatranscriptome_activity_set type doc_count: 55
# metatranscriptome_activity_set execution_resource doc_count: 55
# metatranscriptome_activity_set git_url doc_count: 55
# metatranscriptome_activity_set has_input doc_count: 55
# metatranscriptome_activity_set has_output doc_count: 55
# metatranscriptome_activity_set part_of doc_count: 16
# metatranscriptome_activity_set version doc_count: 0
# metatranscriptome_activity_set id doc_count: 55
# metatranscriptome_activity_set name doc_count: 55
# metatranscriptome_activity_set started_at_time doc_count: 55
# metatranscriptome_activity_set ended_at_time doc_count: 55
# metatranscriptome_activity_set was_informed_by doc_count: 55
# metatranscriptome_activity_set used doc_count: 0
# nom_analysis_activity_set has_calibration doc_count: 749
# nom_analysis_activity_set execution_resource doc_count: 1537
# nom_analysis_activity_set git_url doc_count: 1537
# nom_analysis_activity_set has_input doc_count: 1537
# nom_analysis_activity_set has_output doc_count: 1537
# nom_analysis_activity_set part_of doc_count: 0
# nom_analysis_activity_set type doc_count: 1537
# nom_analysis_activity_set version doc_count: 0
# nom_analysis_activity_set id doc_count: 1537
# nom_analysis_activity_set name doc_count: 0
# nom_analysis_activity_set started_at_time doc_count: 1537
# nom_analysis_activity_set ended_at_time doc_count: 1537
# nom_analysis_activity_set was_informed_by doc_count: 1537
# nom_analysis_activity_set used doc_count: 1537
# metagenome_assembly_set type doc_count: 1386
# metagenome_assembly_set asm_score doc_count: 1370
# metagenome_assembly_set scaffolds doc_count: 1370
# metagenome_assembly_set scaf_logsum doc_count: 1370
# metagenome_assembly_set scaf_powsum doc_count: 1370
# metagenome_assembly_set scaf_max doc_count: 1370
# metagenome_assembly_set scaf_bp doc_count: 1370
# metagenome_assembly_set scaf_n50 doc_count: 1370
# metagenome_assembly_set scaf_n90 doc_count: 1370
# metagenome_assembly_set scaf_l50 doc_count: 1370
# metagenome_assembly_set scaf_l90 doc_count: 1370
# metagenome_assembly_set scaf_n_gt50k doc_count: 1370
# metagenome_assembly_set scaf_l_gt50k doc_count: 1370
# metagenome_assembly_set scaf_pct_gt50k doc_count: 1370
# metagenome_assembly_set contigs doc_count: 1370
# metagenome_assembly_set contig_bp doc_count: 1370
# metagenome_assembly_set ctg_n50 doc_count: 1370
# metagenome_assembly_set ctg_l50 doc_count: 1370
# metagenome_assembly_set ctg_n90 doc_count: 1370
# metagenome_assembly_set ctg_l90 doc_count: 1370
# metagenome_assembly_set ctg_logsum doc_count: 1370
# metagenome_assembly_set ctg_powsum doc_count: 1370
# metagenome_assembly_set ctg_max doc_count: 1370
# metagenome_assembly_set gap_pct doc_count: 1370
# metagenome_assembly_set gc_std doc_count: 1370
# metagenome_assembly_set gc_avg doc_count: 1370
# metagenome_assembly_set num_input_reads doc_count: 816
# metagenome_assembly_set num_aligned_reads doc_count: 816
# metagenome_assembly_set insdc_assembly_identifiers doc_count: 536
# metagenome_assembly_set execution_resource doc_count: 1386
# metagenome_assembly_set git_url doc_count: 1386
# metagenome_assembly_set has_input doc_count: 1386
# metagenome_assembly_set has_output doc_count: 1386
# metagenome_assembly_set part_of doc_count: 1106
# metagenome_assembly_set version doc_count: 536
# metagenome_assembly_set id doc_count: 1386
# metagenome_assembly_set name doc_count: 1386
# metagenome_assembly_set started_at_time doc_count: 1386
# metagenome_assembly_set ended_at_time doc_count: 1386
# metagenome_assembly_set was_informed_by doc_count: 1386
# metagenome_assembly_set used doc_count: 0
# omics_processing_set add_date doc_count: 2166
# omics_processing_set chimera_check doc_count: 0
# omics_processing_set gold_sequencing_project_identifiers doc_count: 1761
# omics_processing_set has_input doc_count: 4101
# omics_processing_set has_output doc_count: 2420
# omics_processing_set insdc_experiment_identifiers doc_count: 0
# omics_processing_set instrument_name doc_count: 3615
# omics_processing_set mod_date doc_count: 2166
# omics_processing_set ncbi_project_name doc_count: 2166
# omics_processing_set nucl_acid_amp doc_count: 0
# omics_processing_set nucl_acid_ext doc_count: 0
# omics_processing_set omics_type doc_count: 4101
# omics_processing_set part_of doc_count: 4101
# omics_processing_set pcr_cond doc_count: 0
# omics_processing_set pcr_primers doc_count: 0
# omics_processing_set principal_investigator doc_count: 2166
# omics_processing_set processing_institution doc_count: 3609
# omics_processing_set samp_vol_we_dna_ext doc_count: 0
# omics_processing_set seq_meth doc_count: 0
# omics_processing_set seq_quality_check doc_count: 0
# omics_processing_set target_gene doc_count: 0
# omics_processing_set target_subfragment doc_count: 0
# omics_processing_set type doc_count: 4101
# omics_processing_set id doc_count: 4101
# omics_processing_set name doc_count: 4101
# omics_processing_set description doc_count: 2340
# omics_processing_set alternative_identifiers doc_count: 0
# field_research_site_set cur_vegetation doc_count: 0
# field_research_site_set elev doc_count: 0
# field_research_site_set geo_loc_name doc_count: 0
# field_research_site_set habitat doc_count: 0
# field_research_site_set lat_lon doc_count: 0
# field_research_site_set local_class doc_count: 0
# field_research_site_set neon_deims_sdr_link doc_count: 0
# field_research_site_set neon_eco_type doc_count: 0
# field_research_site_set neon_soil_type doc_count: 0
# field_research_site_set part_of doc_count: 0
# field_research_site_set soil_type doc_count: 0
# field_research_site_set id doc_count: 110
# field_research_site_set name doc_count: 110
# field_research_site_set description doc_count: 0
# field_research_site_set alternative_identifiers doc_count: 0
# activity_set execution_resource doc_count: 0
# activity_set git_url doc_count: 0
# activity_set has_input doc_count: 0
# activity_set has_output doc_count: 0
# activity_set part_of doc_count: 0
# activity_set type doc_count: 0
# activity_set version doc_count: 0
# activity_set id doc_count: 0
# activity_set name doc_count: 0
# activity_set started_at_time doc_count: 0
# activity_set ended_at_time doc_count: 0
# activity_set was_informed_by doc_count: 0
# activity_set used doc_count: 0
# data_object_set file_size_bytes doc_count: 58419
# data_object_set md5_checksum doc_count: 48071
# data_object_set data_object_type doc_count: 44337
# data_object_set compression_type doc_count: 23373
# data_object_set was_generated_by doc_count: 26076
# data_object_set url doc_count: 54838
# data_object_set type doc_count: 42862
# data_object_set id doc_count: 58419
# data_object_set name doc_count: 58419
# data_object_set description doc_count: 58419
# data_object_set alternative_identifiers doc_count: 23373
# biosample_set neon_biosample_identifiers doc_count: 0
# biosample_set host_taxid doc_count: 401
# biosample_set embargoed doc_count: 0
# biosample_set collected_from doc_count: 416
# biosample_set type doc_count: 2345
# biosample_set img_identifiers doc_count: 1649
# biosample_set samp_name doc_count: 2477
# biosample_set biosample_categories doc_count: 0
# biosample_set part_of doc_count: 2574
# biosample_set id doc_count: 2574
# biosample_set alternative_identifiers doc_count: 336
# biosample_set gold_biosample_identifiers doc_count: 1942
# biosample_set insdc_biosample_identifiers doc_count: 1194
# biosample_set emsl_biosample_identifiers doc_count: 134
# biosample_set igsn_biosample_identifiers doc_count: 0
# biosample_set abs_air_humidity doc_count: 0
# biosample_set add_recov_method doc_count: 0
# biosample_set additional_info doc_count: 0
# biosample_set address doc_count: 0
# biosample_set adj_room doc_count: 0
# biosample_set aero_struc doc_count: 0
# biosample_set agrochem_addition doc_count: 0
# biosample_set air_PM_concen doc_count: 0
# biosample_set air_temp doc_count: 0
# biosample_set air_temp_regm doc_count: 0
# biosample_set al_sat doc_count: 0
# biosample_set al_sat_meth doc_count: 0
# biosample_set alkalinity doc_count: 0
# biosample_set alkalinity_method doc_count: 0
# biosample_set alkyl_diethers doc_count: 0
# biosample_set alt doc_count: 0
# biosample_set aminopept_act doc_count: 0
# biosample_set ammonium doc_count: 0
# biosample_set ammonium_nitrogen doc_count: 103
# biosample_set amount_light doc_count: 0
# biosample_set ances_data doc_count: 0
# biosample_set annual_precpt doc_count: 0
# biosample_set annual_temp doc_count: 0
# biosample_set antibiotic_regm doc_count: 0
# biosample_set api doc_count: 0
# biosample_set arch_struc doc_count: 0
# biosample_set aromatics_pc doc_count: 0
# biosample_set asphaltenes_pc doc_count: 0
# biosample_set atmospheric_data doc_count: 0
# biosample_set avg_dew_point doc_count: 0
# biosample_set avg_occup doc_count: 0
# biosample_set avg_temp doc_count: 0
# biosample_set bac_prod doc_count: 0
# biosample_set bac_resp doc_count: 0
# biosample_set bacteria_carb_prod doc_count: 0
# biosample_set barometric_press doc_count: 0
# biosample_set basin doc_count: 0
# biosample_set bathroom_count doc_count: 0
# biosample_set bedroom_count doc_count: 0
# biosample_set benzene doc_count: 0
# biosample_set biochem_oxygen_dem doc_count: 0
# biosample_set biocide doc_count: 0
# biosample_set biocide_admin_method doc_count: 0
# biosample_set biol_stat doc_count: 0
# biosample_set biomass doc_count: 0
# biosample_set biotic_regm doc_count: 0
# biosample_set biotic_relationship doc_count: 0
# biosample_set bishomohopanol doc_count: 0
# biosample_set blood_press_diast doc_count: 0
# biosample_set blood_press_syst doc_count: 0
# biosample_set bromide doc_count: 0
# biosample_set build_docs doc_count: 0
# biosample_set build_occup_type doc_count: 0
# biosample_set building_setting doc_count: 0
# biosample_set built_struc_age doc_count: 0
# biosample_set built_struc_set doc_count: 0
# biosample_set built_struc_type doc_count: 0
# biosample_set calcium doc_count: 103
# biosample_set carb_dioxide doc_count: 0
# biosample_set carb_monoxide doc_count: 0
# biosample_set carb_nitro_ratio doc_count: 79
# biosample_set ceil_area doc_count: 0
# biosample_set ceil_cond doc_count: 0
# biosample_set ceil_finish_mat doc_count: 0
# biosample_set ceil_struc doc_count: 0
# biosample_set ceil_texture doc_count: 0
# biosample_set ceil_thermal_mass doc_count: 0
# biosample_set ceil_type doc_count: 0
# biosample_set ceil_water_mold doc_count: 0
# biosample_set chem_administration doc_count: 0
# biosample_set chem_mutagen doc_count: 0
# biosample_set chem_oxygen_dem doc_count: 0
# biosample_set chem_treat_method doc_count: 0
# biosample_set chem_treatment doc_count: 0
# biosample_set chimera_check doc_count: 0
# biosample_set chloride doc_count: 0
# biosample_set chlorophyll doc_count: 0
# biosample_set climate_environment doc_count: 0
# biosample_set collection_date doc_count: 2295
# biosample_set conduc doc_count: 0
# biosample_set cool_syst_id doc_count: 0
# biosample_set core field doc_count: 0
# biosample_set crop_rotation doc_count: 0
# biosample_set cult_root_med doc_count: 0
# biosample_set cur_land_use doc_count: 0
# biosample_set cur_vegetation doc_count: 122
# biosample_set cur_vegetation_meth doc_count: 0
# biosample_set date_last_rain doc_count: 0
# biosample_set density doc_count: 0
# biosample_set depos_env doc_count: 0
# biosample_set depth doc_count: 675
# biosample_set dew_point doc_count: 0
# biosample_set diether_lipids doc_count: 0
# biosample_set diss_carb_dioxide doc_count: 0
# biosample_set diss_hydrogen doc_count: 0
# biosample_set diss_inorg_carb doc_count: 0
# biosample_set diss_inorg_nitro doc_count: 0
# biosample_set diss_inorg_phosp doc_count: 0
# biosample_set diss_iron doc_count: 0
# biosample_set diss_org_carb doc_count: 0
# biosample_set diss_org_nitro doc_count: 0
# biosample_set diss_oxygen doc_count: 0
# biosample_set diss_oxygen_fluid doc_count: 0
# biosample_set dna_cont_well doc_count: 0
# biosample_set door_comp_type doc_count: 0
# biosample_set door_cond doc_count: 0
# biosample_set door_direct doc_count: 0
# biosample_set door_loc doc_count: 0
# biosample_set door_mat doc_count: 0
# biosample_set door_move doc_count: 0
# biosample_set door_size doc_count: 0
# biosample_set door_type doc_count: 0
# biosample_set door_type_metal doc_count: 0
# biosample_set door_type_wood doc_count: 0
# biosample_set door_water_mold doc_count: 0
# biosample_set down_par doc_count: 0
# biosample_set drainage_class doc_count: 0
# biosample_set drawings doc_count: 0
# biosample_set ecosystem doc_count: 2574
# biosample_set ecosystem_category doc_count: 2574
# biosample_set ecosystem_subtype doc_count: 2574
# biosample_set ecosystem_type doc_count: 2574
# biosample_set efficiency_percent doc_count: 0
# biosample_set elev doc_count: 1153
# biosample_set elevator doc_count: 0
# biosample_set emulsions doc_count: 0
# biosample_set env_broad_scale doc_count: 2574
# biosample_set env_local_scale doc_count: 2574
# biosample_set env_medium doc_count: 2574
# biosample_set env_package doc_count: 234
# biosample_set environment field doc_count: 0
# biosample_set escalator doc_count: 0
# biosample_set ethylbenzene doc_count: 0
# biosample_set exp_duct doc_count: 0
# biosample_set exp_pipe doc_count: 0
# biosample_set experimental_factor doc_count: 0
# biosample_set ext_door doc_count: 0
# biosample_set ext_wall_orient doc_count: 0
# biosample_set ext_window_orient doc_count: 0
# biosample_set extreme_event doc_count: 0
# biosample_set fao_class doc_count: 0
# biosample_set fertilizer_regm doc_count: 0
# biosample_set field doc_count: 0
# biosample_set filter_type doc_count: 0
# biosample_set fire doc_count: 0
# biosample_set fireplace_type doc_count: 0
# biosample_set flooding doc_count: 0
# biosample_set floor_age doc_count: 0
# biosample_set floor_area doc_count: 0
# biosample_set floor_cond doc_count: 0
# biosample_set floor_count doc_count: 0
# biosample_set floor_finish_mat doc_count: 0
# biosample_set floor_struc doc_count: 0
# biosample_set floor_thermal_mass doc_count: 0
# biosample_set floor_water_mold doc_count: 0
# biosample_set fluor doc_count: 0
# biosample_set freq_clean doc_count: 0
# biosample_set freq_cook doc_count: 0
# biosample_set fungicide_regm doc_count: 0
# biosample_set furniture doc_count: 0
# biosample_set gaseous_environment doc_count: 0
# biosample_set gaseous_substances doc_count: 0
# biosample_set gender_restroom doc_count: 0
# biosample_set genetic_mod doc_count: 0
# biosample_set geo_loc_name doc_count: 2574
# biosample_set glucosidase_act doc_count: 0
# biosample_set gravidity doc_count: 0
# biosample_set gravity doc_count: 0
# biosample_set growth_facil doc_count: 134
# biosample_set growth_habit doc_count: 0
# biosample_set growth_hormone_regm doc_count: 0
# biosample_set hall_count doc_count: 0
# biosample_set handidness doc_count: 0
# biosample_set has numeric value doc_count: 0
# biosample_set has raw value doc_count: 0
# biosample_set has unit doc_count: 0
# biosample_set hc_produced doc_count: 0
# biosample_set hcr doc_count: 0
# biosample_set hcr_fw_salinity doc_count: 0
# biosample_set hcr_geol_age doc_count: 0
# biosample_set hcr_pressure doc_count: 0
# biosample_set hcr_temp doc_count: 0
# biosample_set heat_cool_type doc_count: 0
# biosample_set heat_deliv_loc doc_count: 0
# biosample_set heat_sys_deliv_meth doc_count: 0
# biosample_set heat_system_id doc_count: 0
# biosample_set heavy_metals doc_count: 0
# biosample_set heavy_metals_meth doc_count: 0
# biosample_set height_carper_fiber doc_count: 0
# biosample_set herbicide_regm doc_count: 0
# biosample_set horizon_meth doc_count: 0
# biosample_set host_age doc_count: 0
# biosample_set host_body_habitat doc_count: 0
# biosample_set host_body_product doc_count: 0
# biosample_set host_body_site doc_count: 0
# biosample_set host_body_temp doc_count: 0
# biosample_set host_color doc_count: 0
# biosample_set host_common_name doc_count: 0
# biosample_set host_diet doc_count: 0
# biosample_set host_dry_mass doc_count: 0
# biosample_set host_family_relation doc_count: 0
# biosample_set host_genotype doc_count: 0
# biosample_set host_growth_cond doc_count: 0
# biosample_set host_height doc_count: 0
# biosample_set host_last_meal doc_count: 0
# biosample_set host_length doc_count: 0
# biosample_set host_life_stage doc_count: 0
# biosample_set host_phenotype doc_count: 0
# biosample_set host_sex doc_count: 0
# biosample_set host_shape doc_count: 0
# biosample_set host_subject_id doc_count: 0
# biosample_set host_subspecf_genlin doc_count: 0
# biosample_set host_substrate doc_count: 0
# biosample_set host_symbiont doc_count: 0
# biosample_set host_tot_mass doc_count: 0
# biosample_set host_wet_mass doc_count: 0
# biosample_set humidity doc_count: 0
# biosample_set humidity_regm doc_count: 0
# biosample_set indoor_space doc_count: 0
# biosample_set indoor_surf doc_count: 0
# biosample_set indust_eff_percent doc_count: 0
# biosample_set inorg_particles doc_count: 0
# biosample_set inside_lux doc_count: 0
# biosample_set int_wall_cond doc_count: 0
# biosample_set investigation field doc_count: 0
# biosample_set iw_bt_date_well doc_count: 0
# biosample_set iwf doc_count: 0
# biosample_set last_clean doc_count: 0
# biosample_set lat_lon doc_count: 2574
# biosample_set lbc_thirty doc_count: 103
# biosample_set lbceq doc_count: 103
# biosample_set light_intensity doc_count: 0
# biosample_set light_regm doc_count: 0
# biosample_set light_type doc_count: 0
# biosample_set link_addit_analys doc_count: 0
# biosample_set link_class_info doc_count: 0
# biosample_set link_climate_info doc_count: 0
# biosample_set lithology doc_count: 0
# biosample_set local_class doc_count: 0
# biosample_set local_class_meth doc_count: 0
# biosample_set magnesium doc_count: 103
# biosample_set manganese doc_count: 103
# biosample_set max_occup doc_count: 0
# biosample_set mean_frict_vel doc_count: 0
# biosample_set mean_peak_frict_vel doc_count: 0
# biosample_set mech_struc doc_count: 0
# biosample_set mechanical_damage doc_count: 0
# biosample_set methane doc_count: 0
# biosample_set micro_biomass_meth doc_count: 134
# biosample_set microbial_biomass doc_count: 0
# biosample_set mineral_nutr_regm doc_count: 0
# biosample_set misc_param doc_count: 0
# biosample_set n_alkanes doc_count: 0
# biosample_set nitrate doc_count: 18
# biosample_set nitrate_nitrogen doc_count: 103
# biosample_set nitrite doc_count: 0
# biosample_set nitrite_nitrogen doc_count: 103
# biosample_set nitro doc_count: 0
# biosample_set non_min_nutr_regm doc_count: 0
# biosample_set nucl_acid_amp doc_count: 0
# biosample_set nucl_acid_ext doc_count: 0
# biosample_set nucleic acid sequence source field doc_count: 0
# biosample_set number_pets doc_count: 0
# biosample_set number_plants doc_count: 0
# biosample_set number_resident doc_count: 0
# biosample_set occup_density_samp doc_count: 0
# biosample_set occup_document doc_count: 0
# biosample_set occup_samp doc_count: 0
# biosample_set org_carb doc_count: 0
# biosample_set org_count_qpcr_info doc_count: 0
# biosample_set org_matter doc_count: 0
# biosample_set org_nitro doc_count: 0
# biosample_set org_particles doc_count: 0
# biosample_set organism_count doc_count: 0
# biosample_set owc_tvdss doc_count: 0
# biosample_set oxy_stat_samp doc_count: 0
# biosample_set oxygen doc_count: 0
# biosample_set part_org_carb doc_count: 0
# biosample_set part_org_nitro doc_count: 0
# biosample_set particle_class doc_count: 0
# biosample_set pcr_cond doc_count: 0
# biosample_set pcr_primers doc_count: 0
# biosample_set permeability doc_count: 0
# biosample_set perturbation doc_count: 0
# biosample_set pesticide_regm doc_count: 0
# biosample_set petroleum_hydrocarb doc_count: 0
# biosample_set ph doc_count: 230
# biosample_set ph_meth doc_count: 0
# biosample_set ph_regm doc_count: 0
# biosample_set phaeopigments doc_count: 0
# biosample_set phosphate doc_count: 0
# biosample_set phosplipid_fatt_acid doc_count: 0
# biosample_set photon_flux doc_count: 0
# biosample_set plant_growth_med doc_count: 0
# biosample_set plant_product doc_count: 0
# biosample_set plant_sex doc_count: 0
# biosample_set plant_struc doc_count: 0
# biosample_set pollutants doc_count: 0
# biosample_set pool_dna_extracts doc_count: 0
# biosample_set porosity doc_count: 0
# biosample_set potassium doc_count: 103
# biosample_set pour_point doc_count: 0
# biosample_set pre_treatment doc_count: 0
# biosample_set pres_animal_insect doc_count: 0
# biosample_set pressure doc_count: 0
# biosample_set prev_land_use_meth doc_count: 0
# biosample_set previous_land_use doc_count: 0
# biosample_set primary_prod doc_count: 0
# biosample_set primary_treatment doc_count: 0
# biosample_set prod_rate doc_count: 0
# biosample_set prod_start_date doc_count: 0
# biosample_set profile_position doc_count: 0
# biosample_set quad_pos doc_count: 0
# biosample_set radiation_regm doc_count: 0
# biosample_set rainfall_regm doc_count: 0
# biosample_set reactor_type doc_count: 0
# biosample_set redox_potential doc_count: 0
# biosample_set rel_air_humidity doc_count: 0
# biosample_set rel_humidity_out doc_count: 0
# biosample_set rel_samp_loc doc_count: 0
# biosample_set reservoir doc_count: 0
# biosample_set resins_pc doc_count: 0
# biosample_set room_air_exch_rate doc_count: 0
# biosample_set room_architec_elem doc_count: 0
# biosample_set room_condt doc_count: 0
# biosample_set room_connected doc_count: 0
# biosample_set room_count doc_count: 0
# biosample_set room_dim doc_count: 0
# biosample_set room_door_dist doc_count: 0
# biosample_set room_door_share doc_count: 0
# biosample_set room_hallway doc_count: 0
# biosample_set room_loc doc_count: 0
# biosample_set room_moist_dam_hist doc_count: 0
# biosample_set room_net_area doc_count: 0
# biosample_set room_occup doc_count: 0
# biosample_set room_samp_pos doc_count: 0
# biosample_set room_type doc_count: 0
# biosample_set room_vol doc_count: 0
# biosample_set room_wall_share doc_count: 0
# biosample_set room_window_count doc_count: 0
# biosample_set root_cond doc_count: 0
# biosample_set root_med_carbon doc_count: 0
# biosample_set root_med_macronutr doc_count: 0
# biosample_set root_med_micronutr doc_count: 0
# biosample_set root_med_ph doc_count: 0
# biosample_set root_med_regl doc_count: 0
# biosample_set root_med_solid doc_count: 0
# biosample_set root_med_suppl doc_count: 0
# biosample_set salinity doc_count: 19
# biosample_set salinity_meth doc_count: 0
# biosample_set salt_regm doc_count: 0
# biosample_set samp_capt_status doc_count: 0
# biosample_set samp_collec_device doc_count: 0
# biosample_set samp_collec_method doc_count: 128
# biosample_set samp_collect_point doc_count: 0
# biosample_set samp_dis_stage doc_count: 0
# biosample_set samp_floor doc_count: 0
# biosample_set samp_loc_corr_rate doc_count: 0
# biosample_set samp_mat_process doc_count: 0
# biosample_set samp_md doc_count: 0
# biosample_set samp_preserv doc_count: 0
# biosample_set samp_room_id doc_count: 0
# biosample_set samp_size doc_count: 0
# biosample_set samp_sort_meth doc_count: 0
# biosample_set samp_store_dur doc_count: 0
# biosample_set samp_store_loc doc_count: 0
# biosample_set samp_store_temp doc_count: 134
# biosample_set samp_subtype doc_count: 0
# biosample_set samp_taxon_id doc_count: 1578
# biosample_set samp_time_out doc_count: 0
# biosample_set samp_transport_cond doc_count: 0
# biosample_set samp_tvdss doc_count: 0
# biosample_set samp_type doc_count: 0
# biosample_set samp_vol_we_dna_ext doc_count: 0
# biosample_set samp_weather doc_count: 0
# biosample_set samp_well_name doc_count: 0
# biosample_set saturates_pc doc_count: 0
# biosample_set season doc_count: 0
# biosample_set season_environment doc_count: 0
# biosample_set season_precpt doc_count: 0
# biosample_set season_temp doc_count: 0
# biosample_set season_use doc_count: 0
# biosample_set secondary_treatment doc_count: 0
# biosample_set sediment_type doc_count: 0
# biosample_set seq_meth doc_count: 0
# biosample_set seq_quality_check doc_count: 0
# biosample_set sequencing field doc_count: 0
# biosample_set sewage_type doc_count: 0
# biosample_set shad_dev_water_mold doc_count: 0
# biosample_set shading_device_cond doc_count: 0
# biosample_set shading_device_loc doc_count: 0
# biosample_set shading_device_mat doc_count: 0
# biosample_set shading_device_type doc_count: 0
# biosample_set sieving doc_count: 133
# biosample_set silicate doc_count: 0
# biosample_set size_frac doc_count: 0
# biosample_set size_frac_low doc_count: 0
# biosample_set size_frac_up doc_count: 0
# biosample_set slope_aspect doc_count: 0
# biosample_set slope_gradient doc_count: 0
# biosample_set sludge_retent_time doc_count: 0
# biosample_set sodium doc_count: 0
# biosample_set soil_horizon doc_count: 0
# biosample_set soil_text_measure doc_count: 0
# biosample_set soil_texture_meth doc_count: 0
# biosample_set soil_type doc_count: 0
# biosample_set soil_type_meth doc_count: 0
# biosample_set solar_irradiance doc_count: 0
# biosample_set soluble_inorg_mat doc_count: 0
# biosample_set soluble_org_mat doc_count: 0
# biosample_set soluble_react_phosp doc_count: 0
# biosample_set source_mat_id doc_count: 0
# biosample_set space_typ_state doc_count: 0
# biosample_set specific doc_count: 0
# biosample_set specific_ecosystem doc_count: 2449
# biosample_set specific_humidity doc_count: 0
# biosample_set sr_dep_env doc_count: 0
# biosample_set sr_geol_age doc_count: 0
# biosample_set sr_kerog_type doc_count: 0
# biosample_set sr_lithology doc_count: 0
# biosample_set standing_water_regm doc_count: 0
# biosample_set store_cond doc_count: 134
# biosample_set substructure_type doc_count: 0
# biosample_set sulfate doc_count: 0
# biosample_set sulfate_fw doc_count: 0
# biosample_set sulfide doc_count: 0
# biosample_set surf_air_cont doc_count: 0
# biosample_set surf_humidity doc_count: 0
# biosample_set surf_material doc_count: 0
# biosample_set surf_moisture doc_count: 0
# biosample_set surf_moisture_ph doc_count: 0
# biosample_set surf_temp doc_count: 0
# biosample_set suspend_part_matter doc_count: 0
# biosample_set suspend_solids doc_count: 0
# biosample_set tan doc_count: 0
# biosample_set target_gene doc_count: 0
# biosample_set target_subfragment doc_count: 0
# biosample_set temp doc_count: 19
# biosample_set temp_out doc_count: 0
# biosample_set tertiary_treatment doc_count: 0
# biosample_set tidal_stage doc_count: 0
# biosample_set tillage doc_count: 0
# biosample_set tiss_cult_growth_med doc_count: 0
# biosample_set toluene doc_count: 0
# biosample_set tot_carb doc_count: 0
# biosample_set tot_depth_water_col doc_count: 0
# biosample_set tot_diss_nitro doc_count: 0
# biosample_set tot_inorg_nitro doc_count: 0
# biosample_set tot_iron doc_count: 0
# biosample_set tot_nitro doc_count: 103
# biosample_set tot_nitro_cont_meth doc_count: 0
# biosample_set tot_nitro_content doc_count: 0
# biosample_set tot_org_c_meth doc_count: 0
# biosample_set tot_org_carb doc_count: 6
# biosample_set tot_part_carb doc_count: 0
# biosample_set tot_phosp doc_count: 127
# biosample_set tot_phosphate doc_count: 0
# biosample_set tot_sulfur doc_count: 0
# biosample_set train_line doc_count: 0
# biosample_set train_stat_loc doc_count: 0
# biosample_set train_stop_loc doc_count: 0
# biosample_set turbidity doc_count: 0
# biosample_set tvdss_of_hcr_press doc_count: 0
# biosample_set tvdss_of_hcr_temp doc_count: 0
# biosample_set typ_occup_density doc_count: 0
# biosample_set ventilation_rate doc_count: 0
# biosample_set ventilation_type doc_count: 0
# biosample_set vfa doc_count: 0
# biosample_set vfa_fw doc_count: 0
# biosample_set vis_media doc_count: 0
# biosample_set viscosity doc_count: 0
# biosample_set volatile_org_comp doc_count: 0
# biosample_set wall_area doc_count: 0
# biosample_set wall_const_type doc_count: 0
# biosample_set wall_finish_mat doc_count: 0
# biosample_set wall_height doc_count: 0
# biosample_set wall_loc doc_count: 0
# biosample_set wall_surf_treatment doc_count: 0
# biosample_set wall_texture doc_count: 0
# biosample_set wall_thermal_mass doc_count: 0
# biosample_set wall_water_mold doc_count: 0
# biosample_set wastewater_type doc_count: 0
# biosample_set water_cont_soil_meth doc_count: 0
# biosample_set water_content doc_count: 118
# biosample_set water_current doc_count: 0
# biosample_set water_cut doc_count: 0
# biosample_set water_feat_size doc_count: 0
# biosample_set water_feat_type doc_count: 0
# biosample_set water_prod_rate doc_count: 0
# biosample_set water_temp_regm doc_count: 0
# biosample_set watering_regm doc_count: 0
# biosample_set weekday doc_count: 0
# biosample_set win doc_count: 0
# biosample_set wind_direction doc_count: 0
# biosample_set wind_speed doc_count: 0
# biosample_set window_cond doc_count: 0
# biosample_set window_cover doc_count: 0
# biosample_set window_horiz_pos doc_count: 0
# biosample_set window_loc doc_count: 0
# biosample_set window_mat doc_count: 0
# biosample_set window_open_freq doc_count: 0
# biosample_set window_size doc_count: 0
# biosample_set window_status doc_count: 0
# biosample_set window_type doc_count: 0
# biosample_set window_vert_pos doc_count: 0
# biosample_set window_water_mold doc_count: 0
# biosample_set xylene doc_count: 0
# biosample_set zinc doc_count: 103
# biosample_set add_date doc_count: 2160
# biosample_set community doc_count: 379
# biosample_set habitat doc_count: 2423
# biosample_set host_name doc_count: 431
# biosample_set location doc_count: 2422
# biosample_set mod_date doc_count: 2160
# biosample_set ncbi_taxonomy_name doc_count: 2019
# biosample_set proport_woa_temperature doc_count: 0
# biosample_set salinity_category doc_count: 0
# biosample_set sample_collection_site doc_count: 2245
# biosample_set soluble_iron_micromol doc_count: 0
# biosample_set subsurface_depth doc_count: 1
# biosample_set dna_absorb1 doc_count: 0
# biosample_set dna_absorb2 doc_count: 0
# biosample_set dna_collect_site doc_count: 0
# biosample_set dna_concentration doc_count: 0
# biosample_set dna_cont_type doc_count: 0
# biosample_set dna_container_id doc_count: 0
# biosample_set dna_dnase doc_count: 0
# biosample_set dna_isolate_meth doc_count: 0
# biosample_set dna_organisms doc_count: 0
# biosample_set dna_project_contact doc_count: 0
# biosample_set dna_samp_id doc_count: 0
# biosample_set dna_sample_format doc_count: 0
# biosample_set dna_sample_name doc_count: 0
# biosample_set dna_seq_project doc_count: 0
# biosample_set dna_seq_project_pi doc_count: 0
# biosample_set dna_seq_project_name doc_count: 0
# biosample_set dna_volume doc_count: 0
# biosample_set proposal_dna doc_count: 0
# biosample_set dnase_rna doc_count: 0
# biosample_set proposal_rna doc_count: 0
# biosample_set rna_absorb1 doc_count: 0
# biosample_set rna_absorb2 doc_count: 0
# biosample_set rna_collect_site doc_count: 0
# biosample_set rna_concentration doc_count: 0
# biosample_set rna_cont_type doc_count: 0
# biosample_set rna_cont_well doc_count: 0
# biosample_set rna_container_id doc_count: 0
# biosample_set rna_isolate_meth doc_count: 0
# biosample_set rna_organisms doc_count: 0
# biosample_set rna_project_contact doc_count: 0
# biosample_set rna_samp_id doc_count: 0
# biosample_set rna_sample_format doc_count: 0
# biosample_set rna_sample_name doc_count: 0
# biosample_set rna_seq_project doc_count: 0
# biosample_set rna_seq_project_pi doc_count: 0
# biosample_set rna_seq_project_name doc_count: 0
# biosample_set rna_volume doc_count: 0
# biosample_set collection_date_inc doc_count: 0
# biosample_set collection_time doc_count: 126
# biosample_set collection_time_inc doc_count: 0
# biosample_set experimental_factor_other doc_count: 0
# biosample_set filter_method doc_count: 0
# biosample_set isotope_exposure doc_count: 0
# biosample_set micro_biomass_c_meth doc_count: 0
# biosample_set micro_biomass_n_meth doc_count: 0
# biosample_set microbial_biomass_c doc_count: 0
# biosample_set microbial_biomass_n doc_count: 0
# biosample_set non_microb_biomass doc_count: 0
# biosample_set non_microb_biomass_method doc_count: 0
# biosample_set org_nitro_method doc_count: 0
# biosample_set other_treatment doc_count: 0
# biosample_set start_date_inc doc_count: 0
# biosample_set start_time_inc doc_count: 0
# biosample_set project_id doc_count: 0
# biosample_set replicate_number doc_count: 0
# biosample_set sample_shipped doc_count: 0
# biosample_set sample_type doc_count: 0
# biosample_set technical_reps doc_count: 0
# biosample_set analysis_type doc_count: 134
# biosample_set sample_link doc_count: 1
# biosample_set name doc_count: 2574
# biosample_set description doc_count: 2335
# read_qc_analysis_activity_set type doc_count: 1387
# read_qc_analysis_activity_set input_read_count doc_count: 1371
# read_qc_analysis_activity_set input_base_count doc_count: 536
# read_qc_analysis_activity_set output_read_count doc_count: 1371
# read_qc_analysis_activity_set output_base_count doc_count: 536
# read_qc_analysis_activity_set input_read_bases doc_count: 1371
# read_qc_analysis_activity_set output_read_bases doc_count: 1371
# read_qc_analysis_activity_set version doc_count: 536
# read_qc_analysis_activity_set execution_resource doc_count: 1387
# read_qc_analysis_activity_set git_url doc_count: 1387
# read_qc_analysis_activity_set has_input doc_count: 1387
# read_qc_analysis_activity_set has_output doc_count: 1387
# read_qc_analysis_activity_set part_of doc_count: 1106
# read_qc_analysis_activity_set id doc_count: 1387
# read_qc_analysis_activity_set name doc_count: 1387
# read_qc_analysis_activity_set started_at_time doc_count: 1387
# read_qc_analysis_activity_set ended_at_time doc_count: 1387
# read_qc_analysis_activity_set was_informed_by doc_count: 1387
# read_qc_analysis_activity_set used doc_count: 0
# metaproteomics_analysis_activity_set has_peptide_quantifications doc_count: 52
# metaproteomics_analysis_activity_set execution_resource doc_count: 52
# metaproteomics_analysis_activity_set git_url doc_count: 52
# metaproteomics_analysis_activity_set has_input doc_count: 52
# metaproteomics_analysis_activity_set has_output doc_count: 52
# metaproteomics_analysis_activity_set part_of doc_count: 0
# metaproteomics_analysis_activity_set type doc_count: 52
# metaproteomics_analysis_activity_set version doc_count: 0
# metaproteomics_analysis_activity_set id doc_count: 52
# metaproteomics_analysis_activity_set name doc_count: 52
# metaproteomics_analysis_activity_set started_at_time doc_count: 52
# metaproteomics_analysis_activity_set ended_at_time doc_count: 52
# metaproteomics_analysis_activity_set was_informed_by doc_count: 52
# metaproteomics_analysis_activity_set used doc_count: 0
# metagenome_sequencing_set execution_resource doc_count: 545
# metagenome_sequencing_set git_url doc_count: 545
# metagenome_sequencing_set has_input doc_count: 545
# metagenome_sequencing_set has_output doc_count: 545
# metagenome_sequencing_set part_of doc_count: 545
# metagenome_sequencing_set type doc_count: 545
# metagenome_sequencing_set version doc_count: 545
# metagenome_sequencing_set id doc_count: 545
# metagenome_sequencing_set name doc_count: 545
# metagenome_sequencing_set started_at_time doc_count: 545
# metagenome_sequencing_set ended_at_time doc_count: 545
# metagenome_sequencing_set was_informed_by doc_count: 545
# metagenome_sequencing_set used doc_count: 0
# metagenome_annotation_set type doc_count: 1148
# metagenome_annotation_set gold_analysis_project_identifiers doc_count: 536
# metagenome_annotation_set execution_resource doc_count: 1148
# metagenome_annotation_set git_url doc_count: 1148
# metagenome_annotation_set has_input doc_count: 1148
# metagenome_annotation_set has_output doc_count: 1148
# metagenome_annotation_set part_of doc_count: 1106
# metagenome_annotation_set version doc_count: 536
# metagenome_annotation_set id doc_count: 1148
# metagenome_annotation_set name doc_count: 1148
# metagenome_annotation_set started_at_time doc_count: 1148
# metagenome_annotation_set ended_at_time doc_count: 1148
# metagenome_annotation_set was_informed_by doc_count: 1148
# metagenome_annotation_set used doc_count: 0
# material_sample_set id doc_count: 0
# material_sample_set name doc_count: 0
# material_sample_set description doc_count: 0
# material_sample_set alternative_identifiers doc_count: 0
# mags_set type doc_count: 1090
# mags_set input_contig_num doc_count: 1089
# mags_set binned_contig_num doc_count: 1089
# mags_set too_short_contig_num doc_count: 1089
# mags_set low_depth_contig_num doc_count: 1089
# mags_set unbinned_contig_num doc_count: 1089
# mags_set mags_list doc_count: 1089
# mags_set execution_resource doc_count: 1090
# mags_set git_url doc_count: 1090
# mags_set has_input doc_count: 1090
# mags_set has_output doc_count: 1090
# mags_set part_of doc_count: 1089
# mags_set version doc_count: 535
# mags_set id doc_count: 1090
# mags_set name doc_count: 1090
# mags_set started_at_time doc_count: 1090
# mags_set ended_at_time doc_count: 1090
# mags_set was_informed_by doc_count: 1090
# mags_set used doc_count: 0
# metabolomics_analysis_set has_calibration doc_count: 209
# metabolomics_analysis_set has_metabolite_quantifications doc_count: 209
# metabolomics_analysis_set execution_resource doc_count: 209
# metabolomics_analysis_set git_url doc_count: 209
# metabolomics_analysis_set has_input doc_count: 209
# metabolomics_analysis_set has_output doc_count: 209
# metabolomics_analysis_set part_of doc_count: 0
# metabolomics_analysis_set type doc_count: 209
# metabolomics_analysis_set version doc_count: 0
# metabolomics_analysis_set id doc_count: 209
# metabolomics_analysis_set name doc_count: 0
# metabolomics_analysis_set started_at_time doc_count: 209
# metabolomics_analysis_set ended_at_time doc_count: 209
# metabolomics_analysis_set was_informed_by doc_count: 209
# metabolomics_analysis_set used doc_count: 209
# read_based_taxonomy_analysis_activity_set type doc_count: 1430
# read_based_taxonomy_analysis_activity_set execution_resource doc_count: 1430
# read_based_taxonomy_analysis_activity_set git_url doc_count: 1430
# read_based_taxonomy_analysis_activity_set has_input doc_count: 1430
# read_based_taxonomy_analysis_activity_set has_output doc_count: 1430
# read_based_taxonomy_analysis_activity_set part_of doc_count: 518
# read_based_taxonomy_analysis_activity_set version doc_count: 518
# read_based_taxonomy_analysis_activity_set id doc_count: 1430
# read_based_taxonomy_analysis_activity_set name doc_count: 1430
# read_based_taxonomy_analysis_activity_set started_at_time doc_count: 1430
# read_based_taxonomy_analysis_activity_set ended_at_time doc_count: 1430
# read_based_taxonomy_analysis_activity_set was_informed_by doc_count: 1430
# read_based_taxonomy_analysis_activity_set used doc_count: 0

# %%
# populated_slot_count_frame = pd.DataFrame(populated_slot_counts)
# populated_slot_count_frame.to_csv('../local/populated_slot_counts.csv')

# %%
write_dicts_to_tsv(populated_slot_counts, output_file)
