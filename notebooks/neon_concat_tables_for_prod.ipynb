# %%
# import os
import pprint
import csv
import pandas as pd
from nmdc_schema.nmdc import FieldResearchSite, Biosample, ControlledIdentifiedTermValue, OntologyClass, QuantityValue, \
    GeolocationValue, TextValue
from linkml_runtime.dumpers import yaml_dumper
import re
import random
import requests
import requests_cache

# %% [markdown]
# - https://data.neonscience.org/api/v0/releases/RELEASE-2023/data/package/DP1.10107.001/GUAN/2019-09?package=expanded
#   - obtains a zip archive
# - https://data.neonscience.org/api/v0/data/package/DP1.10107.001/GUAN/2019-09?package=expanded&release=RELEASE-2023
#   - obtains a zip archive
# - https://data.neonscience.org/api/v0/releases/RELEASE-2023/data/DP1.10107.001/GUAN/2019-09?package=expanded
#   - obtains a JSON object with links to files
# - https://data.neonscience.org/api/v0/releases/RELEASE-2023/data/DP1.10107.001/GUAN/2019-09/NEON.D04.GUAN.DP1.10107.001.mms_rawDataFiles.2019-09.expanded.20230113T225344Z.csv?package=expanded
#   - obtains a CSV file,
#   - but you have to know the exact name of the file
#
#
# ## Releases
# - RELEASE-2023
# - RELEASE-2022
# - RELEASE-2021
#
# ## Some Domain Info
# - https://www.geobabble.org/~hnw/neon/withindomainrep/
# - https://www.geobabble.org/~hnw/neon/withindomainrep/neondomains2.html
# - https://www.neonscience.org/field-sites/about-field-sites
#
# ## "File categories" for DP1.10107.001, "Soil microbe metagenome sequences"
#
# ```JSON
# {'EML',
#  'categoricalCodes',
#  'mms_metagenomeDnaExtraction',
#  'mms_metagenomeSequencing',
#  'mms_rawDataFiles',
#  'readme',
#  'validation',
#  'variables'}
# ```
#
# Soil physical and chemical properties, periodic https://data.neonscience.org/data-products/DP1.10086.001
#
# File naming conventions: https://www.neonscience.org/data-samples/data-management/data-formats-conventions
#
# Named location details can be retrieved from https://data.neonscience.org/api/v0/locations/{namedLocation}, like https://data.neonscience.org/api/v0/locations/ABBY_004.basePlot.bgc
#
# note the availability locationParent and locationChildren... could just iterate over everything top down?!
#
# Another source of info:
# - locationPropertyName	"Value for DEIMS-SDR Site ID"
# - locationPropertyValue	"https://deims.org/0e39569d-ff81-4b78-9c34-b07309504d80"
#
# https://deims.org/api/sites/0e39569d-ff81-4b78-9c34-b07309504d80
#
# even more geospatially specific:  https://data.neonscience.org/api/v0/locations/ABBY_004.basePlot.bgc.21, but locations with that pattern may not be present in our data
#
# ## Sample lookups may be helpful:
# - https://data.neonscience.org/api/v0/samples/classes?sampleTag=BART_004-M-3-28-20140819
# - https://data.neonscience.org/api/v0/samples/view?sampleTag=BART_004-M-3-28-20140819&sampleClass=sls_soilCoreCollection_in.sampleID
# - https://data.neonscience.org/api/v0/samples/download?sampleTag=BART_004-M-3-28-20140819&sampleClass=sls_soilCoreCollection_in.sampleID&degree=999
#
# the neonUtilities R package provides a helpful table_types dataframe
#
# ----
#
# consider the sample with a `uid` of	'8af5ccf9-e0bc-466d-bf36-357ba5adc3a0' in the `sls_soilCoreCollection` table
#
# | sls_soilCoreCollection   column | value                                |
# |---------------------------------|--------------------------------------|
# | uid                             | 8af5ccf9-e0bc-466d-bf36-357ba5adc3a0 |
# | domainID                        | D16                                  |
# | siteID                          | ABBY                                 |
# | plotID                          | ABBY_002                             |
# | namedLocation                   | ABBY_002.basePlot.bgc                |
# | plotType                        | distributed                          |
# | nlcdClass                       | grasslandHerbaceous                  |
# | subplotID                       |                                      |
# | coreCoordinateX                 | 13                                   |
# | coreCoordinateY                 | 4                                    |
# | geodeticDatum                   | WGS84                                |
# | decimalLatitude                 | 45.739055                            |
# | decimalLongitude                | -122.309112                          |
# | coordinateUncertainty           | 20.1                                 |
# | elevation                       | 638.4                                |
# | elevationUncertainty            | 0.1                                  |
# | samplingProtocolVersion         | NEON.DOC.014048vG                    |
# | startDate                       | 2016-10-04T17:10Z                    |
# | collectDate                     | 2016-10-04T17:10Z                    |
# | sampleTiming                    | dryWetTransition                     |
# | biophysicalCriteria             |                                      |
# | eventID                         |                                      |
# | standingWaterDepth              | 0                                    |
# | nTransBoutType                  | No                                   |
# | boutType                        | microbes                             |
# | samplingImpractical             |                                      |
# | incubationMethod                |                                      |
# | incubationCondition             |                                      |
# | sampleID                        | ABBY_002-O-13-4-20161004             |
# | sampleCode                      |                                      |
# | toxicodendronPossible           |                                      |
# | horizon                         | O                                    |
# | horizonDetails                  |                                      |
# | soilTemp                        | 9.8                                  |
# | litterDepth                     | 1                                    |
# | sampleTopDepth                  | 0                                    |
# | sampleBottomDepth               | 8                                    |
# | sampleExtent                    | entire                               |
# | soilSamplingDevice              | brownie cutter                       |
# | soilCoreCount                   | 2                                    |
# | geneticSampleID                 | ABBY_002-O-13-4-20161004-GEN         |
# | geneticSampleCode               |                                      |
# | geneticSampleCondition          | OK                                   |
# | geneticSamplePrepMethod         |                                      |
# | geneticArchiveSample1ID         | ABBY_002-O-13-4-20161004-GA1         |
# | geneticArchiveSample1Code       |                                      |
# | geneticArchiveSample2ID         | ABBY_002-O-13-4-20161004-GA2         |
# | geneticArchiveSample2Code       |                                      |
# | geneticArchiveSample3ID         | ABBY_002-O-13-4-20161004-GA3         |
# | geneticArchiveSample3Code       |                                      |
# | geneticArchiveSample4ID         | ABBY_002-O-13-4-20161004-GA4         |
# | geneticArchiveSample4Code       |                                      |
# | geneticArchiveSample5ID         | ABBY_002-O-13-4-20161004-GA5         |
# | geneticArchiveSample5Code       |                                      |
# | geneticArchiveSamplePrepMethod  |                                      |
# | geneticArchiveContainer         |                                      |
# | biomassID                       |                                      |
# | biomassCode                     |                                      |
# | biomassSampleCondition          |                                      |
# | remarks                         |                                      |
# | collectedBy                     | dcrandall@neoninc.org                |
# | dataQF                          |                                      |
#
# The `sampleID` is 'ABBY_002-O-13-4-20161004'
#
# https://data.neonscience.org/api/v0/samples/classes?sampleTag=ABBY_002-O-13-4-20161004
#
# ```json
# {"data":{"sampleClasses":["sls_soilMoisture_in.moistureSampleID","sls_soilCoreCollection_in.sampleID"]}}
# ```
#
# https://data.neonscience.org/api/v0/samples/download?sampleTag=ABBY_002-O-13-4-20161004&sampleClass=sls_soilCoreCollection_in.sampleID&degree=999
#
# ### omitting "sampleEvents"
#
# ```json
# {
#   "sampleClass": "sls_soilCoreCollection_in.sampleID",
#   "sampleTag": "ABBY_002-O-13-4-20161004",
#   "barcode": null,
#   "archiveGuid": null,
#   "sampleUuid": "b59a39c8-14d5-4405-ba4c-bb0d773706e4",
#   "parentSampleIdentifiers": null,
#   "childSampleIdentifiers": [
#     {
#       "sampleUuid": "0238c5f7-04c3-43e3-ba08-48bbed2baa23",
#       "sampleTag": "ABBY_002-O-13-4-20161004",
#       "sampleClass": "sls_soilMoisture_in.moistureSampleID",
#       "barcode": null,
#       "archiveGuid": null
#     },
#     {
#       "sampleUuid": "7870c58d-138f-47ea-846e-f9de5f336586",
#       "sampleTag": "ABBY_002-O-13-4-20161004-GA1",
#       "sampleClass": "sls_soilCoreCollection_in.geneticArchiveSample1ID",
#       "barcode": null,
#       "archiveGuid": null
#     },
#     {
#       "sampleUuid": "17b7ed77-abee-419e-b496-9e684440c8fd",
#       "sampleTag": "ABBY_002-O-13-4-20161004-GA2",
#       "sampleClass": "sls_soilCoreCollection_in.geneticArchiveSample2ID",
#       "barcode": null,
#       "archiveGuid": null
#     },
#     {
#       "sampleUuid": "e8f4c6fe-2730-43d1-8034-220207ecd2e7",
#       "sampleTag": "ABBY_002-O-13-4-20161004-GA3",
#       "sampleClass": "sls_soilCoreCollection_in.geneticArchiveSample3ID",
#       "barcode": null,
#       "archiveGuid": null
#     },
#     {
#       "sampleUuid": "c464c41f-6d14-4a28-b99b-95758c8fee7a",
#       "sampleTag": "ABBY_002-O-13-4-20161004-GA4",
#       "sampleClass": "sls_soilCoreCollection_in.geneticArchiveSample4ID",
#       "barcode": null,
#       "archiveGuid": null
#     },
#     {
#       "sampleUuid": "d2c2bbab-a546-4558-b411-974fd473acc7",
#       "sampleTag": "ABBY_002-O-13-4-20161004-GA5",
#       "sampleClass": "sls_soilCoreCollection_in.geneticArchiveSample5ID",
#       "barcode": null,
#       "archiveGuid": null
#     },
#     {
#       "sampleUuid": "4c54c342-2917-4812-bdf0-ff6700e8b7c5",
#       "sampleTag": "ABBY_002-O-13-4-20161004-GEN",
#       "sampleClass": "sls_soilCoreCollection_in.geneticSampleID",
#       "barcode": null,
#       "archiveGuid": null
#     },
#     {
#       "sampleUuid": "49be492a-57a1-4300-b7d4-025d96be99b4",
#       "sampleTag": "ABBY_002-O-13-4-20161004-PH",
#       "sampleClass": "sls_soilpH_in.pHSampleID",
#       "barcode": null,
#       "archiveGuid": null
#     }
#   ]
# }
# ```
#
# what can we learn about
#
# | sls_soilCoreCollection   column | value                                |
# |---------------------------------|--------------------------------------|
# | domainID                        | D16                                  |
# | siteID                          | ABBY                                 |
# | plotID                          | ABBY_002                             |
# | namedLocation                   | ABBY_002.basePlot.bgc                |
#
# domainID, siteID and namedLocation can be found with the location endpoint, https://data.neonscience.org/api/v0/locations/{location}
#
# - domainID: little useful data
# - siteID: could use 'USA: {Value for State Abbreviation}, {locationDescription}' for `geo_loc_name`
#   - also useful: Value for HABITAT, Value for TypeEco, Value for TypeSoil
# - namedLocation: could use locationDecimalLatitude, locationDecimalLongitude for `lat_lon`, locationElevation, Value for National Land Cover Database (2001), Value for Slope aspect, Value for Slope gradient, Value for Soil type order
#
#
# note there is no `subplotID`... I could swear I've seen those in my research before
#
# we can use `nlcdClass` either as is in some vegetation/land cover/land use slot, or infer one of the MIxS environmental trial slots from it
#
#
# slots to possibly populate:
# - (controlled values) from https://microbiomedata.github.io/nmdc-schema/gold_path_field/
#   - ecosystem
#   - ecosystem_category
#   - ecosystem_type
#   - ecosystem_subtype
#   - specific_ecosystem
# - https://microbiomedata.github.io/nmdc-schema/cur_land_use/ (https://microbiomedata.github.io/nmdc-schema/CurLandUseEnum/)
# - https://microbiomedata.github.io/nmdc-schema/cur_vegetation/ (TEXT VALUE)
# - https://microbiomedata.github.io/nmdc-schema/depos_env/ https://microbiomedata.github.io/nmdc-schema/DeposEnvEnum/
# - https://microbiomedata.github.io/nmdc-schema/env_broad_scale/ (subclasses of biome, http://purl.obolibrary.org/obo/ENVO_00000428)
# - https://microbiomedata.github.io/nmdc-schema/env_local_scale/ ("EnvO terms which are of smaller spatial grain than your entry for env_broad_scale")
# - https://microbiomedata.github.io/nmdc-schema/env_medium/ (subclass of 'environmental material', http://purl.obolibrary.org/obo/ENVO_00010483)
# - https://microbiomedata.github.io/nmdc-schema/fao_class/ (https://microbiomedata.github.io/nmdc-schema/FaoClassEnum/)
# - https://microbiomedata.github.io/nmdc-schema/local_class/ (TEXT VALUE)
# - https://microbiomedata.github.io/nmdc-schema/soil_type/ (envo terms?)
#
# might also want to look at neon's categorical codes files
#
# still haven't taken any action on the demis data
#
# nlcd xml file:
#
# it looks like nlcd data is present in EnvO
#
# are all of the neon records tied to the same nlcd release?

# %%
requests_cache.install_cache('neon_cache', backend='sqlite', expire_after=43200) # 12 hours

# %%
# product_code = "DP1.10107.001"
product_code = "DP1.10086.001"
release_tag = "RELEASE-2023"

# %%
useful_file_categories = [
    'mms_metagenomeDnaExtraction',
    'mms_metagenomeSequencing',
    'mms_rawDataFiles',
    'sls_bgcSubsampling',
    'sls_metagenomicsPooling',
    'sls_soilChemistry',
    'sls_soilCoreCollection',
    'sls_soilMoisture',
    'sls_soilpH',
]

{ 'ntr_externalLab',
 'ntr_internalLab',
 'ntr_internalLabBlanks',

  'EML',
 'categoricalCodes',

 'readme',
 'sls_bgcSubsampling',
 'sls_metagenomicsPooling',
 'sls_soilChemistry',
 'sls_soilCoreCollection',
 'sls_soilMoisture',
 'sls_soilpH',
 'validation',
 'variables'}
# Out:
# {'EML',
#  'categoricalCodes',
#  'ntr_externalLab',
#  'ntr_internalLab',
#  'ntr_internalLabBlanks',
#  'readme',
#  'sls_bgcSubsampling',
#  'sls_metagenomicsPooling',
#  'sls_soilChemistry',
#  'sls_soilCoreCollection',
#  'sls_soilMoisture',
#  'sls_soilpH',
#  'validation',
#  'variables'}

# %%
# neon_dl_dir = "/Users/MAM/Downloads/NEON_seq-metagenomic-microbe-soil"
# neon_dl_dir_tokens = neon_dl_dir.split("/")
# neon_basename = neon_dl_dir_tokens[-1]
# output_file = f"../local/{neon_basename}.tsv"

# %%
def write_dicts_to_tsv(data, filename):
    fieldnames = data[0].keys()  # Assume all dictionaries have the same keys

    with open(filename, 'w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames, delimiter='\t')
        writer.writeheader()
        writer.writerows(data)

# %%
def remove_unwanted_characters(string):
    # Use regex to match characters that are not in [A-Za-z0-9]
    pattern = r'[^A-Za-z0-9]'
    # Replace the unwanted characters with an empty string
    cleaned_string = re.sub(pattern, '', string)
    return cleaned_string

# %%
# subdirectories = [name for name in os.listdir(neon_dl_dir) if os.path.isdir(os.path.join(neon_dl_dir, name))]
#
# len_list = []
# token_dict_list = []
# for i in subdirectories:
#     tokens = i.split(".")
#     len_list.append(len(tokens))
#     temp = {
#         "data_owner": tokens[0],
#         "geographical_domain": tokens[1],
#         "siteCode": tokens[2],
#         "productCode": f"{tokens[3]}.{tokens[4]}.{tokens[5]}",
#         "year-month": tokens[6],
#         "package": tokens[7],
#         "timestamp": tokens[8],
#         "releaseTag": tokens[9],
#     }
#     token_dict_list.append(temp)

# %%
# write_dicts_to_tsv(token_dict_list, output_file)

# %%
# first_token_dict = token_dict_list[0]
# pprint.pprint(first_token_dict)

# %%
# product_code = first_token_dict['productCode']
# release_tag = first_token_dict['releaseTag']

# %%
url = f"https://data.neonscience.org/api/v0/products/{product_code}?release={release_tag}"
response = requests.get(url).json()
site_wise = response['data']['siteCodes']

# %%
# ONLY FOR RETRIEVING TABLES
# is caching making this any faster? it does for the other API requests

# todo add the ability to iterate over products
file_categories = set()
df_dict = {}

for i in site_wise:
    availableDataUrls = i['availableDataUrls']
    for j in availableDataUrls:
        data_files_response = requests.get(j).json()
        if 'data' not in data_files_response:
            print("Skipping", j)
            continue
        if 'files' not in data_files_response['data']:
            print("Skipping", j)
            continue
        data_file_objects = data_files_response['data']['files']
        for k in data_file_objects:
            data_file_name = k['name']
            print(data_file_name)
            data_file_name_tokens = data_file_name.split(".")
            if len(data_file_name_tokens) < 6:
                print("Skipping", data_file_name)
                continue
            data_file_name_dict = {
                "data_owner": data_file_name_tokens[0],
                "geographical_domain": data_file_name_tokens[1],
                "siteCode": data_file_name_tokens[2],
                "productCode": f"{data_file_name_tokens[3]}.{data_file_name_tokens[4]}.{data_file_name_tokens[5]}",
                "file_category": data_file_name_tokens[6],
                # "timestamp": data_file_name_tokens[7],
                # "extension": data_file_name_tokens[8],
            }

            file_categories.add(data_file_name_dict['file_category'])
            if data_file_name_dict['file_category'] in useful_file_categories:
                if data_file_name_dict['file_category'] in df_dict:
                    more = pd.read_csv(k['url'])
                    df_dict[data_file_name_dict['file_category']] = pd.concat(
                        [df_dict[data_file_name_dict['file_category']], more], ignore_index=True)
                else:
                    df_dict[data_file_name_dict['file_category']] = pd.read_csv(k['url'])

for k, v in df_dict.items():
    print(k)
    deduped = v.drop_duplicates()
    deduped.to_csv(f"../local/{k}.csv", index=False)

pprint.pprint(file_categories)

# %%
sls_soilCoreCollection = pd.read_csv("../local/sls_soilCoreCollection.csv", low_memory=False) # only required if the data frames created from neon requests, and stored in df_dict, aren't sill in memory

# # otherwise
# sls_soilCoreCollection = df_dict['sls_soilCoreCollection']

print(sls_soilCoreCollection.shape)
# should have done deduplication BEFORE creating the dataframes or saving the files
#   WHY are we getting duplicate rows? (exactly 2x?)

sls_soilCoreCollection = sls_soilCoreCollection.drop_duplicates()
print(sls_soilCoreCollection.shape)
# Out:
# (28723, 62)
# (28723, 62)

# %%
print(sls_soilCoreCollection.columns)
# Out:
# Index(['uid', 'domainID', 'siteID', 'plotID', 'namedLocation', 'plotType',
#        'nlcdClass', 'subplotID', 'coreCoordinateX', 'coreCoordinateY',
#        'geodeticDatum', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertainty', 'elevation', 'elevationUncertainty',
#        'samplingProtocolVersion', 'startDate', 'collectDate', 'sampleTiming',
#        'biophysicalCriteria', 'eventID', 'standingWaterDepth',
#        'nTransBoutType', 'boutType', 'samplingImpractical', 'incubationMethod',
#        'incubationCondition', 'sampleID', 'sampleCode',
#        'toxicodendronPossible', 'horizon', 'horizonDetails', 'soilTemp',
#        'litterDepth', 'sampleTopDepth', 'sampleBottomDepth', 'sampleExtent',
#        'soilSamplingDevice', 'soilCoreCount', 'geneticSampleID',
#        'geneticSampleCode', 'geneticSampleCondition',
#        'geneticSamplePrepMethod', 'geneticArchiveSample1ID',
#        'geneticArchiveSample1Code', 'geneticArchiveSample2ID',
#        'geneticArchiveSample2Code', 'geneticArchiveSample3ID',
#        'geneticArchiveSample3Code', 'geneticArchiveSample4ID',
#        'geneticArchiveSample4Code', 'geneticArchiveSample5ID',
#        'geneticArchiveSample5Code', 'geneticArchiveSamplePrepMethod',
#        'geneticArchiveContainer', 'biomassID', 'biomassCode',
#        'biomassSampleCondition', 'remarks', 'collectedBy', 'dataQF'],
#       dtype='object')

# %%
print(sls_soilCoreCollection.head())
# Out:
#                                     uid domainID siteID    plotID  \
# 0  8af5ccf9-e0bc-466d-bf36-357ba5adc3a0      D16   ABBY  ABBY_002
# 1  ba0fb254-9d65-40fe-bdde-6c9d9d7136c7      D16   ABBY  ABBY_002
# 2  ebf65071-8b5e-4f25-8c11-324564274a5b      D16   ABBY  ABBY_002
# 3  9d4ff542-12db-411c-be8e-f629c0813b38      D16   ABBY  ABBY_004
# 4  f0d08cd0-7a54-4b8d-a0a0-9997dec91381      D16   ABBY  ABBY_004
#
#            namedLocation     plotType            nlcdClass  subplotID  \
# 0  ABBY_002.basePlot.bgc  distributed  grasslandHerbaceous        NaN
# 1  ABBY_002.basePlot.bgc  distributed  grasslandHerbaceous        NaN
# 2  ABBY_002.basePlot.bgc  distributed  grasslandHerbaceous        NaN
# 3  ABBY_004.basePlot.bgc  distributed           shrubScrub        NaN
# 4  ABBY_004.basePlot.bgc  distributed           shrubScrub        NaN
#
#    coreCoordinateX  coreCoordinateY  ...           geneticArchiveSample5ID  \
# 0             13.0              4.0  ...      ABBY_002-O-13-4-20161004-GA5
# 1             21.5              9.0  ...    ABBY_002-O-21.5-9-20161004-GA5
# 2              0.5             35.5  ...  ABBY_002-O-0.5-35.5-20161004-GA5
# 3              0.5             38.5  ...  ABBY_004-O-0.5-38.5-20161004-GA5
# 4             38.5             20.0  ...   ABBY_004-M-38.5-20-20161004-GA5
#
#    geneticArchiveSample5Code  geneticArchiveSamplePrepMethod  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    geneticArchiveContainer  biomassID  biomassCode biomassSampleCondition  \
# 0                      NaN        NaN          NaN                    NaN
# 1                      NaN        NaN          NaN                    NaN
# 2                      NaN        NaN          NaN                    NaN
# 3                      NaN        NaN          NaN                    NaN
# 4                      NaN        NaN          NaN                    NaN
#
#   remarks            collectedBy dataQF
# 0     NaN  dcrandall@neoninc.org    NaN
# 1     NaN  dcrandall@neoninc.org    NaN
# 2     NaN  dcrandall@neoninc.org    NaN
# 3     NaN  dcrandall@neoninc.org    NaN
# 4     NaN  dcrandall@neoninc.org    NaN
#
# [5 rows x 62 columns]

# %%
# print(sls_soilCoreCollection['domainID'].value_counts())

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJhdWQiOiJodHRwczovL2RhdGEubmVvbnNjaWVuY2Uub3JnL2FwaS92MC8iLCJzdWIiOiJNQU1AbGJsLmdvdiIsInNjb3BlIjoicmF0ZTpwdWJsaWMiLCJpc3MiOiJodHRwczovL2RhdGEubmVvbnNjaWVuY2Uub3JnLyIsImV4cCI6MTg0MDYzMTY3MywiaWF0IjoxNjgyOTUxNjczLCJlbWFpbCI6Ik1BTUBsYmwuZ292In0.H0P7ke_WL7syECGAA4khEddZ8f6sR__vA3TFherLVt8I1omtYNjspqwWZh42ZkoCbCmRTIr4b4OG8uqPhICv8g"

headers = {'X-API-Token': token}

url_base = "https://data.neonscience.org/api/v0/locations"

# %%
unique_domains = sls_soilCoreCollection['domainID'].unique()
unique_domains.sort()
domains = []

for idx, i in enumerate(unique_domains):
    print(i)
    url = f"{url_base}/{i}"
    response = requests.get(url, headers=headers).json()
    domain_id = f"nmdc:frsite-99-{response['data']['domainCode']}"
    domain = FieldResearchSite(id=domain_id, name=response['data']['locationName'],
                               description=response['data']['locationDescription'])
    domains.append(domain)
# print(yaml_dumper.dumps(domains))
# Out:
# D01
# D02
# D03
# D04
# D05
# D06
# D07
# D08
# D09
# D10
# D11
# D12
# D13
# D14
# D15
# D16
# D17
# D18
# D19
# D20

# %%
# print(yaml_dumper.dumps(sites))

# %%
unique_named_locations = sls_soilCoreCollection['namedLocation'].unique()
unique_named_locations.sort()
named_locations = []
location_count = len(unique_named_locations)

for idx, i in enumerate(unique_named_locations):
    # print(i)
    print(f"{i} = {idx + 1} of {location_count}")
    url = f"{url_base}/{i}"
    response = requests.get(url, headers=headers).json()
    location_id = f"nmdc:frsite-99-{remove_unwanted_characters(response['data']['locationName'])}"
    if 'data' not in response:
        print("Skipping", i)
        continue
    location = FieldResearchSite(
        id=location_id,
        name=response['data']['locationName'],
        description=response['data']['locationDescription'],
    )
    if 'siteCode' in response['data']:
        site_id = f"nmdc:frsite-99-{response['data']['siteCode']}"
        location.part_of = [site_id]
    else:
        print("No siteCode for", i)

    # list of single-key dicts
    location_properties_dict = {}
    location_properties_list = response['data']['locationProperties']
    for l in location_properties_list:
        if 'locationPropertyValue' in l and l['locationPropertyValue'] and 'locationPropertyName' in l:
            substring_to_remove = "Value for "

            # Check if the input string starts with the substring
            if l['locationPropertyName'].startswith(substring_to_remove):
                # Remove the substring from the beginning of the string
                succinct_name = l['locationPropertyName'][len(substring_to_remove):]
            else:
                # The input string does not start with the substring
                succinct_name = l['locationPropertyName']

            location_properties_dict[succinct_name] = l['locationPropertyValue']

    if "National Land Cover Database (2001)" in location_properties_dict:
        cur_vegetation_text_val = TextValue(
            has_raw_value=location_properties_dict["National Land Cover Database (2001)"])

        location.cur_vegetation = cur_vegetation_text_val

    if "Soil type order" in location_properties_dict:
        soil_type_text_val = TextValue(has_raw_value=location_properties_dict["Soil type order"])
        location.local_class = soil_type_text_val

    named_locations.append(location)
# Out:
# ABBY_001.basePlot.bgc = 1 of 549
# ABBY_002.basePlot.bgc = 2 of 549
# ABBY_003.basePlot.bgc = 3 of 549
# ABBY_004.basePlot.bgc = 4 of 549
# ABBY_006.basePlot.bgc = 5 of 549
# ABBY_023.basePlot.bgc = 6 of 549
# ABBY_061.basePlot.bgc = 7 of 549
# ABBY_062.basePlot.bgc = 8 of 549
# ABBY_063.basePlot.bgc = 9 of 549
# ABBY_070.basePlot.bgc = 10 of 549
# BARR_001.basePlot.bgc = 11 of 549
# BARR_002.basePlot.bgc = 12 of 549
# BARR_003.basePlot.bgc = 13 of 549
# BARR_004.basePlot.bgc = 14 of 549
# BARR_005.basePlot.bgc = 15 of 549
# BARR_006.basePlot.bgc = 16 of 549
# BARR_051.basePlot.bgc = 17 of 549
# BARR_052.basePlot.bgc = 18 of 549
# BARR_053.basePlot.bgc = 19 of 549
# BARR_054.basePlot.bgc = 20 of 549
# BART_001.basePlot.bgc = 21 of 549
# BART_002.basePlot.bgc = 22 of 549
# BART_003.basePlot.bgc = 23 of 549
# BART_004.basePlot.bgc = 24 of 549
# BART_005.basePlot.bgc = 25 of 549
# BART_006.basePlot.bgc = 26 of 549
# BART_023.basePlot.bgc = 27 of 549
# BART_024.basePlot.bgc = 28 of 549
# BART_028.basePlot.bgc = 29 of 549
# BART_032.basePlot.bgc = 30 of 549
# BART_033.basePlot.bgc = 31 of 549
# BART_034.basePlot.bgc = 32 of 549
# BART_036.basePlot.bgc = 33 of 549
# BART_040.basePlot.bgc = 34 of 549
# BART_042.basePlot.bgc = 35 of 549
# BART_071.basePlot.bgc = 36 of 549
# BLAN_001.basePlot.bgc = 37 of 549
# BLAN_002.basePlot.bgc = 38 of 549
# BLAN_003.basePlot.bgc = 39 of 549
# BLAN_004.basePlot.bgc = 40 of 549
# BLAN_005.basePlot.bgc = 41 of 549
# BLAN_006.basePlot.bgc = 42 of 549
# BLAN_007.basePlot.bgc = 43 of 549
# BLAN_031.basePlot.bgc = 44 of 549
# BLAN_032.basePlot.bgc = 45 of 549
# BLAN_033.basePlot.bgc = 46 of 549
# BLAN_038.basePlot.bgc = 47 of 549
# BLAN_041.basePlot.bgc = 48 of 549
# BONA_001.basePlot.bgc = 49 of 549
# BONA_002.basePlot.bgc = 50 of 549
# BONA_004.basePlot.bgc = 51 of 549
# BONA_006.basePlot.bgc = 52 of 549
# BONA_009.basePlot.bgc = 53 of 549
# BONA_013.basePlot.bgc = 54 of 549
# BONA_070.basePlot.bgc = 55 of 549
# BONA_071.basePlot.bgc = 56 of 549
# BONA_080.basePlot.bgc = 57 of 549
# BONA_084.basePlot.bgc = 58 of 549
# CLBJ_001.basePlot.bgc = 59 of 549
# CLBJ_002.basePlot.bgc = 60 of 549
# CLBJ_003.basePlot.bgc = 61 of 549
# CLBJ_006.basePlot.bgc = 62 of 549
# CLBJ_031.basePlot.bgc = 63 of 549
# CLBJ_032.basePlot.bgc = 64 of 549
# CLBJ_033.basePlot.bgc = 65 of 549
# CLBJ_034.basePlot.bgc = 66 of 549
# CLBJ_035.basePlot.bgc = 67 of 549
# CLBJ_038.basePlot.bgc = 68 of 549
# CLBJ_040.basePlot.bgc = 69 of 549
# CPER_001.basePlot.bgc = 70 of 549
# CPER_002.basePlot.bgc = 71 of 549
# CPER_003.basePlot.bgc = 72 of 549
# CPER_004.basePlot.bgc = 73 of 549
# CPER_005.basePlot.bgc = 74 of 549
# CPER_006.basePlot.bgc = 75 of 549
# CPER_007.basePlot.bgc = 76 of 549
# CPER_018.basePlot.bgc = 77 of 549
# CPER_045.basePlot.bgc = 78 of 549
# CPER_046.basePlot.bgc = 79 of 549
# CPER_047.basePlot.bgc = 80 of 549
# CPER_048.basePlot.bgc = 81 of 549
# DCFS_003.basePlot.bgc = 82 of 549
# DCFS_004.basePlot.bgc = 83 of 549
# DCFS_006.basePlot.bgc = 84 of 549
# DCFS_007.basePlot.bgc = 85 of 549
# DCFS_008.basePlot.bgc = 86 of 549
# DCFS_009.basePlot.bgc = 87 of 549
# DCFS_062.basePlot.bgc = 88 of 549
# DCFS_063.basePlot.bgc = 89 of 549
# DCFS_065.basePlot.bgc = 90 of 549
# DCFS_067.basePlot.bgc = 91 of 549
# DEJU_001.basePlot.bgc = 92 of 549
# DEJU_002.basePlot.bgc = 93 of 549
# DEJU_006.basePlot.bgc = 94 of 549
# DEJU_009.basePlot.bgc = 95 of 549
# DEJU_014.basePlot.bgc = 96 of 549
# DEJU_015.basePlot.bgc = 97 of 549
# DEJU_045.basePlot.bgc = 98 of 549
# DEJU_046.basePlot.bgc = 99 of 549
# DEJU_047.basePlot.bgc = 100 of 549
# DEJU_048.basePlot.bgc = 101 of 549
# DELA_001.basePlot.bgc = 102 of 549
# DELA_002.basePlot.bgc = 103 of 549
# DELA_003.basePlot.bgc = 104 of 549
# DELA_004.basePlot.bgc = 105 of 549
# DELA_005.basePlot.bgc = 106 of 549
# DELA_014.basePlot.bgc = 107 of 549
# DELA_037.basePlot.bgc = 108 of 549
# DELA_038.basePlot.bgc = 109 of 549
# DELA_040.basePlot.bgc = 110 of 549
# DELA_041.basePlot.bgc = 111 of 549
# DSNY_001.basePlot.bgc = 112 of 549
# DSNY_002.basePlot.bgc = 113 of 549
# DSNY_003.basePlot.bgc = 114 of 549
# DSNY_004.basePlot.bgc = 115 of 549
# DSNY_005.basePlot.bgc = 116 of 549
# DSNY_006.basePlot.bgc = 117 of 549
# DSNY_009.basePlot.bgc = 118 of 549
# DSNY_016.basePlot.bgc = 119 of 549
# DSNY_021.basePlot.bgc = 120 of 549
# DSNY_025.basePlot.bgc = 121 of 549
# DSNY_041.basePlot.bgc = 122 of 549
# DSNY_042.basePlot.bgc = 123 of 549
# DSNY_043.basePlot.bgc = 124 of 549
# DSNY_044.basePlot.bgc = 125 of 549
# GRSM_001.basePlot.bgc = 126 of 549
# GRSM_002.basePlot.bgc = 127 of 549
# GRSM_003.basePlot.bgc = 128 of 549
# GRSM_006.basePlot.bgc = 129 of 549
# GRSM_007.basePlot.bgc = 130 of 549
# GRSM_016.basePlot.bgc = 131 of 549
# GRSM_047.basePlot.bgc = 132 of 549
# GRSM_050.basePlot.bgc = 133 of 549
# GRSM_051.basePlot.bgc = 134 of 549
# GRSM_055.basePlot.bgc = 135 of 549
# GRSM_058.basePlot.bgc = 136 of 549
# GRSM_059.basePlot.bgc = 137 of 549
# GRSM_060.basePlot.bgc = 138 of 549
# GUAN_001.basePlot.bgc = 139 of 549
# GUAN_002.basePlot.bgc = 140 of 549
# GUAN_003.basePlot.bgc = 141 of 549
# GUAN_004.basePlot.bgc = 142 of 549
# GUAN_005.basePlot.bgc = 143 of 549
# GUAN_006.basePlot.bgc = 144 of 549
# GUAN_007.basePlot.bgc = 145 of 549
# GUAN_042.basePlot.bgc = 146 of 549
# GUAN_043.basePlot.bgc = 147 of 549
# GUAN_048.basePlot.bgc = 148 of 549
# GUAN_049.basePlot.bgc = 149 of 549
# HARV_001.basePlot.bgc = 150 of 549
# HARV_002.basePlot.bgc = 151 of 549
# HARV_004.basePlot.bgc = 152 of 549
# HARV_005.basePlot.bgc = 153 of 549
# HARV_010.basePlot.bgc = 154 of 549
# HARV_013.basePlot.bgc = 155 of 549
# HARV_016.basePlot.bgc = 156 of 549
# HARV_020.basePlot.bgc = 157 of 549
# HARV_021.basePlot.bgc = 158 of 549
# HARV_033.basePlot.bgc = 159 of 549
# HARV_034.basePlot.bgc = 160 of 549
# HARV_035.basePlot.bgc = 161 of 549
# HARV_037.basePlot.bgc = 162 of 549
# HEAL_001.basePlot.bgc = 163 of 549
# HEAL_004.basePlot.bgc = 164 of 549
# HEAL_005.basePlot.bgc = 165 of 549
# HEAL_010.basePlot.bgc = 166 of 549
# HEAL_011.basePlot.bgc = 167 of 549
# HEAL_025.basePlot.bgc = 168 of 549
# HEAL_045.basePlot.bgc = 169 of 549
# HEAL_046.basePlot.bgc = 170 of 549
# HEAL_047.basePlot.bgc = 171 of 549
# HEAL_048.basePlot.bgc = 172 of 549
# JERC_001.basePlot.bgc = 173 of 549
# JERC_002.basePlot.bgc = 174 of 549
# JERC_003.basePlot.bgc = 175 of 549
# JERC_004.basePlot.bgc = 176 of 549
# JERC_005.basePlot.bgc = 177 of 549
# JERC_006.basePlot.bgc = 178 of 549
# JERC_008.basePlot.bgc = 179 of 549
# JERC_047.basePlot.bgc = 180 of 549
# JERC_048.basePlot.bgc = 181 of 549
# JERC_049.basePlot.bgc = 182 of 549
# JERC_050.basePlot.bgc = 183 of 549
# JORN_001.basePlot.bgc = 184 of 549
# JORN_002.basePlot.bgc = 185 of 549
# JORN_003.basePlot.bgc = 186 of 549
# JORN_004.basePlot.bgc = 187 of 549
# JORN_005.basePlot.bgc = 188 of 549
# JORN_006.basePlot.bgc = 189 of 549
# JORN_042.basePlot.bgc = 190 of 549
# JORN_044.basePlot.bgc = 191 of 549
# JORN_045.basePlot.bgc = 192 of 549
# JORN_047.basePlot.bgc = 193 of 549
# KONA_001.basePlot.bgc = 194 of 549
# KONA_002.basePlot.bgc = 195 of 549
# KONA_003.basePlot.bgc = 196 of 549
# KONA_004.basePlot.bgc = 197 of 549
# KONA_005.basePlot.bgc = 198 of 549
# KONA_006.basePlot.bgc = 199 of 549
# KONA_048.basePlot.bgc = 200 of 549
# KONA_054.basePlot.bgc = 201 of 549
# KONA_057.basePlot.bgc = 202 of 549
# KONA_059.basePlot.bgc = 203 of 549
# KONZ_001.basePlot.bgc = 204 of 549
# KONZ_002.basePlot.bgc = 205 of 549
# KONZ_003.basePlot.bgc = 206 of 549
# KONZ_004.basePlot.bgc = 207 of 549
# KONZ_005.basePlot.bgc = 208 of 549
# KONZ_024.basePlot.bgc = 209 of 549
# KONZ_042.basePlot.bgc = 210 of 549
# KONZ_043.basePlot.bgc = 211 of 549
# KONZ_045.basePlot.bgc = 212 of 549
# KONZ_046.basePlot.bgc = 213 of 549
# LAJA_001.basePlot.bgc = 214 of 549
# LAJA_002.basePlot.bgc = 215 of 549
# LAJA_003.basePlot.bgc = 216 of 549
# LAJA_004.basePlot.bgc = 217 of 549
# LAJA_005.basePlot.bgc = 218 of 549
# LAJA_015.basePlot.bgc = 219 of 549
# LAJA_042.basePlot.bgc = 220 of 549
# LAJA_044.basePlot.bgc = 221 of 549
# LAJA_046.basePlot.bgc = 222 of 549
# LAJA_051.basePlot.bgc = 223 of 549
# LENO_001.basePlot.bgc = 224 of 549
# LENO_002.basePlot.bgc = 225 of 549
# LENO_003.basePlot.bgc = 226 of 549
# LENO_004.basePlot.bgc = 227 of 549
# LENO_005.basePlot.bgc = 228 of 549
# LENO_006.basePlot.bgc = 229 of 549
# LENO_061.basePlot.bgc = 230 of 549
# LENO_062.basePlot.bgc = 231 of 549
# LENO_063.basePlot.bgc = 232 of 549
# LENO_064.basePlot.bgc = 233 of 549
# MLBS_001.basePlot.bgc = 234 of 549
# MLBS_002.basePlot.bgc = 235 of 549
# MLBS_003.basePlot.bgc = 236 of 549
# MLBS_005.basePlot.bgc = 237 of 549
# MLBS_006.basePlot.bgc = 238 of 549
# MLBS_007.basePlot.bgc = 239 of 549
# MLBS_061.basePlot.bgc = 240 of 549
# MLBS_063.basePlot.bgc = 241 of 549
# MLBS_064.basePlot.bgc = 242 of 549
# MLBS_067.basePlot.bgc = 243 of 549
# MOAB_001.basePlot.bgc = 244 of 549
# MOAB_002.basePlot.bgc = 245 of 549
# MOAB_003.basePlot.bgc = 246 of 549
# MOAB_004.basePlot.bgc = 247 of 549
# MOAB_005.basePlot.bgc = 248 of 549
# MOAB_006.basePlot.bgc = 249 of 549
# MOAB_044.basePlot.bgc = 250 of 549
# MOAB_045.basePlot.bgc = 251 of 549
# MOAB_046.basePlot.bgc = 252 of 549
# MOAB_047.basePlot.bgc = 253 of 549
# NIWO_001.basePlot.bgc = 254 of 549
# NIWO_002.basePlot.bgc = 255 of 549
# NIWO_003.basePlot.bgc = 256 of 549
# NIWO_004.basePlot.bgc = 257 of 549
# NIWO_005.basePlot.bgc = 258 of 549
# NIWO_006.basePlot.bgc = 259 of 549
# NIWO_008.basePlot.bgc = 260 of 549
# NIWO_040.basePlot.bgc = 261 of 549
# NIWO_041.basePlot.bgc = 262 of 549
# NIWO_042.basePlot.bgc = 263 of 549
# NIWO_043.basePlot.bgc = 264 of 549
# NOGP_001.basePlot.bgc = 265 of 549
# NOGP_002.basePlot.bgc = 266 of 549
# NOGP_003.basePlot.bgc = 267 of 549
# NOGP_005.basePlot.bgc = 268 of 549
# NOGP_006.basePlot.bgc = 269 of 549
# NOGP_012.basePlot.bgc = 270 of 549
# NOGP_041.basePlot.bgc = 271 of 549
# NOGP_061.basePlot.bgc = 272 of 549
# NOGP_062.basePlot.bgc = 273 of 549
# NOGP_064.basePlot.bgc = 274 of 549
# NOGP_065.basePlot.bgc = 275 of 549
# OAES_001.basePlot.bgc = 276 of 549
# OAES_002.basePlot.bgc = 277 of 549
# OAES_003.basePlot.bgc = 278 of 549
# OAES_004.basePlot.bgc = 279 of 549
# OAES_005.basePlot.bgc = 280 of 549
# OAES_006.basePlot.bgc = 281 of 549
# OAES_007.basePlot.bgc = 282 of 549
# OAES_008.basePlot.bgc = 283 of 549
# OAES_009.basePlot.bgc = 284 of 549
# OAES_010.basePlot.bgc = 285 of 549
# OAES_011.basePlot.bgc = 286 of 549
# OAES_012.basePlot.bgc = 287 of 549
# OAES_042.basePlot.bgc = 288 of 549
# OAES_043.basePlot.bgc = 289 of 549
# OAES_044.basePlot.bgc = 290 of 549
# OAES_045.basePlot.bgc = 291 of 549
# ONAQ_002.basePlot.bgc = 292 of 549
# ONAQ_003.basePlot.bgc = 293 of 549
# ONAQ_004.basePlot.bgc = 294 of 549
# ONAQ_005.basePlot.bgc = 295 of 549
# ONAQ_006.basePlot.bgc = 296 of 549
# ONAQ_007.basePlot.bgc = 297 of 549
# ONAQ_008.basePlot.bgc = 298 of 549
# ONAQ_009.basePlot.bgc = 299 of 549
# ONAQ_010.basePlot.bgc = 300 of 549
# ONAQ_012.basePlot.bgc = 301 of 549
# ONAQ_017.basePlot.bgc = 302 of 549
# ONAQ_041.basePlot.bgc = 303 of 549
# ONAQ_042.basePlot.bgc = 304 of 549
# ONAQ_043.basePlot.bgc = 305 of 549
# ONAQ_044.basePlot.bgc = 306 of 549
# ORNL_001.basePlot.bgc = 307 of 549
# ORNL_002.basePlot.bgc = 308 of 549
# ORNL_003.basePlot.bgc = 309 of 549
# ORNL_004.basePlot.bgc = 310 of 549
# ORNL_006.basePlot.bgc = 311 of 549
# ORNL_021.basePlot.bgc = 312 of 549
# ORNL_027.basePlot.bgc = 313 of 549
# ORNL_029.basePlot.bgc = 314 of 549
# ORNL_031.basePlot.bgc = 315 of 549
# ORNL_036.basePlot.bgc = 316 of 549
# ORNL_037.basePlot.bgc = 317 of 549
# ORNL_043.basePlot.bgc = 318 of 549
# ORNL_046.basePlot.bgc = 319 of 549
# ORNL_049.basePlot.bgc = 320 of 549
# ORNL_053.basePlot.bgc = 321 of 549
# OSBS_001.basePlot.bgc = 322 of 549
# OSBS_002.basePlot.bgc = 323 of 549
# OSBS_003.basePlot.bgc = 324 of 549
# OSBS_004.basePlot.bgc = 325 of 549
# OSBS_005.basePlot.bgc = 326 of 549
# OSBS_006.basePlot.bgc = 327 of 549
# OSBS_022.basePlot.bgc = 328 of 549
# OSBS_023.basePlot.bgc = 329 of 549
# OSBS_025.basePlot.bgc = 330 of 549
# OSBS_026.basePlot.bgc = 331 of 549
# OSBS_027.basePlot.bgc = 332 of 549
# OSBS_029.basePlot.bgc = 333 of 549
# OSBS_031.basePlot.bgc = 334 of 549
# OSBS_063.basePlot.bgc = 335 of 549
# PUUM_004.basePlot.bgc = 336 of 549
# PUUM_006.basePlot.bgc = 337 of 549
# PUUM_007.basePlot.bgc = 338 of 549
# PUUM_010.basePlot.bgc = 339 of 549
# PUUM_014.basePlot.bgc = 340 of 549
# PUUM_015.basePlot.bgc = 341 of 549
# PUUM_031.basePlot.bgc = 342 of 549
# PUUM_032.basePlot.bgc = 343 of 549
# PUUM_034.basePlot.bgc = 344 of 549
# PUUM_036.basePlot.bgc = 345 of 549
# PUUM_040.basePlot.bgc = 346 of 549
# PUUM_042.basePlot.bgc = 347 of 549
# RMNP_002.basePlot.bgc = 348 of 549
# RMNP_004.basePlot.bgc = 349 of 549
# RMNP_005.basePlot.bgc = 350 of 549
# RMNP_006.basePlot.bgc = 351 of 549
# RMNP_013.basePlot.bgc = 352 of 549
# RMNP_019.basePlot.bgc = 353 of 549
# RMNP_041.basePlot.bgc = 354 of 549
# RMNP_043.basePlot.bgc = 355 of 549
# RMNP_044.basePlot.bgc = 356 of 549
# RMNP_045.basePlot.bgc = 357 of 549
# SCBI_002.basePlot.bgc = 358 of 549
# SCBI_003.basePlot.bgc = 359 of 549
# SCBI_004.basePlot.bgc = 360 of 549
# SCBI_005.basePlot.bgc = 361 of 549
# SCBI_006.basePlot.bgc = 362 of 549
# SCBI_008.basePlot.bgc = 363 of 549
# SCBI_010.basePlot.bgc = 364 of 549
# SCBI_012.basePlot.bgc = 365 of 549
# SCBI_033.basePlot.bgc = 366 of 549
# SCBI_045.basePlot.bgc = 367 of 549
# SCBI_046.basePlot.bgc = 368 of 549
# SCBI_047.basePlot.bgc = 369 of 549
# SCBI_049.basePlot.bgc = 370 of 549
# SCBI_067.basePlot.bgc = 371 of 549
# SERC_001.basePlot.bgc = 372 of 549
# SERC_002.basePlot.bgc = 373 of 549
# SERC_003.basePlot.bgc = 374 of 549
# SERC_004.basePlot.bgc = 375 of 549
# SERC_005.basePlot.bgc = 376 of 549
# SERC_007.basePlot.bgc = 377 of 549
# SERC_044.basePlot.bgc = 378 of 549
# SERC_045.basePlot.bgc = 379 of 549
# SERC_046.basePlot.bgc = 380 of 549
# SERC_047.basePlot.bgc = 381 of 549
# SERC_049.basePlot.bgc = 382 of 549
# SJER_001.basePlot.bgc = 383 of 549
# SJER_002.basePlot.bgc = 384 of 549
# SJER_003.basePlot.bgc = 385 of 549
# SJER_004.basePlot.bgc = 386 of 549
# SJER_005.basePlot.bgc = 387 of 549
# SJER_025.basePlot.bgc = 388 of 549
# SJER_045.basePlot.bgc = 389 of 549
# SJER_046.basePlot.bgc = 390 of 549
# SJER_047.basePlot.bgc = 391 of 549
# SJER_048.basePlot.bgc = 392 of 549
# SOAP_001.basePlot.bgc = 393 of 549
# SOAP_002.basePlot.bgc = 394 of 549
# SOAP_003.basePlot.bgc = 395 of 549
# SOAP_004.basePlot.bgc = 396 of 549
# SOAP_005.basePlot.bgc = 397 of 549
# SOAP_006.basePlot.bgc = 398 of 549
# SOAP_025.basePlot.bgc = 399 of 549
# SOAP_031.basePlot.bgc = 400 of 549
# SOAP_043.basePlot.bgc = 401 of 549
# SOAP_044.basePlot.bgc = 402 of 549
# SOAP_045.basePlot.bgc = 403 of 549
# SRER_001.basePlot.bgc = 404 of 549
# SRER_002.basePlot.bgc = 405 of 549
# SRER_003.basePlot.bgc = 406 of 549
# SRER_004.basePlot.bgc = 407 of 549
# SRER_005.basePlot.bgc = 408 of 549
# SRER_006.basePlot.bgc = 409 of 549
# SRER_043.basePlot.bgc = 410 of 549
# SRER_047.basePlot.bgc = 411 of 549
# SRER_052.basePlot.bgc = 412 of 549
# SRER_053.basePlot.bgc = 413 of 549
# STEI_001.basePlot.bgc = 414 of 549
# STEI_002.basePlot.bgc = 415 of 549
# STEI_003.basePlot.bgc = 416 of 549
# STEI_004.basePlot.bgc = 417 of 549
# STEI_005.basePlot.bgc = 418 of 549
# STEI_008.basePlot.bgc = 419 of 549
# STEI_021.basePlot.bgc = 420 of 549
# STEI_047.basePlot.bgc = 421 of 549
# STEI_053.basePlot.bgc = 422 of 549
# STEI_059.basePlot.bgc = 423 of 549
# STEI_060.basePlot.bgc = 424 of 549
# STER_003.basePlot.bgc = 425 of 549
# STER_004.basePlot.bgc = 426 of 549
# STER_005.basePlot.bgc = 427 of 549
# STER_006.basePlot.bgc = 428 of 549
# STER_007.basePlot.bgc = 429 of 549
# STER_010.basePlot.bgc = 430 of 549
# STER_011.basePlot.bgc = 431 of 549
# STER_012.basePlot.bgc = 432 of 549
# STER_016.basePlot.bgc = 433 of 549
# STER_018.basePlot.bgc = 434 of 549
# STER_026.basePlot.bgc = 435 of 549
# STER_027.basePlot.bgc = 436 of 549
# STER_028.basePlot.bgc = 437 of 549
# STER_029.basePlot.bgc = 438 of 549
# STER_031.basePlot.bgc = 439 of 549
# STER_032.basePlot.bgc = 440 of 549
# STER_033.basePlot.bgc = 441 of 549
# STER_034.basePlot.bgc = 442 of 549
# STER_035.basePlot.bgc = 443 of 549
# TALL_001.basePlot.bgc = 444 of 549
# TALL_002.basePlot.bgc = 445 of 549
# TALL_003.basePlot.bgc = 446 of 549
# TALL_004.basePlot.bgc = 447 of 549
# TALL_006.basePlot.bgc = 448 of 549
# TALL_007.basePlot.bgc = 449 of 549
# TALL_009.basePlot.bgc = 450 of 549
# TALL_044.basePlot.bgc = 451 of 549
# TALL_047.basePlot.bgc = 452 of 549
# TALL_051.basePlot.bgc = 453 of 549
# TALL_054.basePlot.bgc = 454 of 549
# TEAK_001.basePlot.bgc = 455 of 549
# TEAK_002.basePlot.bgc = 456 of 549
# TEAK_003.basePlot.bgc = 457 of 549
# TEAK_004.basePlot.bgc = 458 of 549
# TEAK_005.basePlot.bgc = 459 of 549
# TEAK_009.basePlot.bgc = 460 of 549
# TEAK_025.basePlot.bgc = 461 of 549
# TEAK_043.basePlot.bgc = 462 of 549
# TEAK_044.basePlot.bgc = 463 of 549
# TEAK_045.basePlot.bgc = 464 of 549
# TEAK_046.basePlot.bgc = 465 of 549
# TOOL_001.basePlot.bgc = 466 of 549
# TOOL_002.basePlot.bgc = 467 of 549
# TOOL_003.basePlot.bgc = 468 of 549
# TOOL_004.basePlot.bgc = 469 of 549
# TOOL_005.basePlot.bgc = 470 of 549
# TOOL_006.basePlot.bgc = 471 of 549
# TOOL_041.basePlot.bgc = 472 of 549
# TOOL_042.basePlot.bgc = 473 of 549
# TOOL_043.basePlot.bgc = 474 of 549
# TOOL_044.basePlot.bgc = 475 of 549
# TREE_001.basePlot.bgc = 476 of 549
# TREE_002.basePlot.bgc = 477 of 549
# TREE_003.basePlot.bgc = 478 of 549
# TREE_004.basePlot.bgc = 479 of 549
# TREE_006.basePlot.bgc = 480 of 549
# TREE_007.basePlot.bgc = 481 of 549
# TREE_014.basePlot.bgc = 482 of 549
# TREE_015.basePlot.bgc = 483 of 549
# TREE_041.basePlot.bgc = 484 of 549
# TREE_046.basePlot.bgc = 485 of 549
# TREE_049.basePlot.bgc = 486 of 549
# TREE_050.basePlot.bgc = 487 of 549
# UKFS_001.basePlot.bgc = 488 of 549
# UKFS_002.basePlot.bgc = 489 of 549
# UKFS_003.basePlot.bgc = 490 of 549
# UKFS_004.basePlot.bgc = 491 of 549
# UKFS_005.basePlot.bgc = 492 of 549
# UKFS_009.basePlot.bgc = 493 of 549
# UKFS_031.basePlot.bgc = 494 of 549
# UKFS_032.basePlot.bgc = 495 of 549
# UKFS_043.basePlot.bgc = 496 of 549
# UKFS_044.basePlot.bgc = 497 of 549
# UNDE_001.basePlot.bgc = 498 of 549
# UNDE_002.basePlot.bgc = 499 of 549
# UNDE_003.basePlot.bgc = 500 of 549
# UNDE_006.basePlot.bgc = 501 of 549
# UNDE_007.basePlot.bgc = 502 of 549
# UNDE_008.basePlot.bgc = 503 of 549
# UNDE_010.basePlot.bgc = 504 of 549
# UNDE_013.basePlot.bgc = 505 of 549
# UNDE_014.basePlot.bgc = 506 of 549
# UNDE_017.basePlot.bgc = 507 of 549
# UNDE_019.basePlot.bgc = 508 of 549
# UNDE_027.basePlot.bgc = 509 of 549
# UNDE_032.basePlot.bgc = 510 of 549
# UNDE_034.basePlot.bgc = 511 of 549
# UNDE_035.basePlot.bgc = 512 of 549
# UNDE_037.basePlot.bgc = 513 of 549
# UNDE_038.basePlot.bgc = 514 of 549
# UNDE_043.basePlot.bgc = 515 of 549
# UNDE_044.basePlot.bgc = 516 of 549
# WOOD_001.basePlot.bgc = 517 of 549
# WOOD_002.basePlot.bgc = 518 of 549
# WOOD_003.basePlot.bgc = 519 of 549
# WOOD_004.basePlot.bgc = 520 of 549
# WOOD_005.basePlot.bgc = 521 of 549
# WOOD_021.basePlot.bgc = 522 of 549
# WOOD_022.basePlot.bgc = 523 of 549
# WOOD_024.basePlot.bgc = 524 of 549
# WOOD_042.basePlot.bgc = 525 of 549
# WOOD_043.basePlot.bgc = 526 of 549
# WOOD_044.basePlot.bgc = 527 of 549
# WOOD_045.basePlot.bgc = 528 of 549
# WREF_001.basePlot.bgc = 529 of 549
# WREF_003.basePlot.bgc = 530 of 549
# WREF_004.basePlot.bgc = 531 of 549
# WREF_005.basePlot.bgc = 532 of 549
# WREF_007.basePlot.bgc = 533 of 549
# WREF_008.basePlot.bgc = 534 of 549
# WREF_070.basePlot.bgc = 535 of 549
# WREF_071.basePlot.bgc = 536 of 549
# WREF_072.basePlot.bgc = 537 of 549
# WREF_073.basePlot.bgc = 538 of 549
# YELL_001.basePlot.bgc = 539 of 549
# YELL_002.basePlot.bgc = 540 of 549
# YELL_003.basePlot.bgc = 541 of 549
# YELL_005.basePlot.bgc = 542 of 549
# YELL_009.basePlot.bgc = 543 of 549
# YELL_012.basePlot.bgc = 544 of 549
# YELL_016.basePlot.bgc = 545 of 549
# YELL_046.basePlot.bgc = 546 of 549
# YELL_048.basePlot.bgc = 547 of 549
# YELL_051.basePlot.bgc = 548 of 549
# YELL_052.basePlot.bgc = 549 of 549

# %%
# print(yaml_dumper.dumps(named_locations))

# %%
unique_sites = sls_soilCoreCollection['siteID'].unique()
unique_sites.sort()
sites = []
for idx, i in enumerate(unique_sites):
    print(i)
    url = f"{url_base}/{i}"
    response = requests.get(url, headers=headers).json()
    site_id = f"nmdc:frsite-99-{response['data']['siteCode']}"
    site = FieldResearchSite(
        id=site_id,
        name=response['data']['locationName'],
        description=response['data']['locationDescription'],
    )
    if 'domainCode' in response['data']:
        domain_id = f"nmdc:frsite-99-{response['data']['domainCode']}"
        site.part_of = [domain_id]
    if 'locationElevation' in response['data']:
        site.elev = QuantityValue(
            has_numeric_value=response['data']['locationElevation'],
            has_unit="meters")
    if 'locationDecimalLatitude' in response['data'] and 'locationDecimalLongitude' in response['data']:
        site.lat_lon = GeolocationValue(
            latitude=response['data']['locationDecimalLatitude'],
            longitude=response['data']['locationDecimalLongitude'],
        )

    # list of single-key dicts
    location_properties_dict = {}
    location_properties_list = response['data']['locationProperties']
    for l in location_properties_list:
        if 'locationPropertyValue' in l and l['locationPropertyValue'] and 'locationPropertyName' in l:
            substring_to_remove = "Value for "

            # Check if the input string starts with the substring
            if l['locationPropertyName'].startswith(substring_to_remove):
                # Remove the substring from the beginning of the string
                succinct_name = l['locationPropertyName'][len(substring_to_remove):]
            else:
                # The input string does not start with the substring
                succinct_name = l['locationPropertyName']

            location_properties_dict[succinct_name] = l['locationPropertyValue']

    if 'Country' in location_properties_dict and 'State Abbreviation' in location_properties_dict and 'locationDescription' in \
            response['data']:
        geo_loc_name_obj = TextValue(
            has_raw_value=f"{location_properties_dict['Country']}: {location_properties_dict['State Abbreviation']}, {response['data']['locationDescription']}")
        site.geo_loc_name = geo_loc_name_obj

    if "DEIMS-SDR Site ID" in location_properties_dict:
        prefix = "https://deims.org/api/sites"
        browsable = location_properties_dict["DEIMS-SDR Site ID"]
        browsable_tokens = browsable.split("/")
        site_code = browsable_tokens[-1]
        # convert https://deims.org/0e39569d-ff81-4b78-9c34-b07309504d80
        # to https://deims.org/api/sites/0e39569d-ff81-4b78-9c34-b07309504d80
        site.neon_deims_sdr_link = f"{prefix}/{site_code}"

    if "HABITAT" in location_properties_dict:
        site.habitat = location_properties_dict["HABITAT"]  # gold term... controlled vocabulary?

    if "TypeSoil" in location_properties_dict:
        soil_type_text_val = TextValue(has_raw_value=location_properties_dict["TypeSoil"])
        site.neon_soil_type = location_properties_dict["TypeSoil"]

    if "TypeEco" in location_properties_dict:
        site.neon_eco_type = location_properties_dict[
            "TypeEco"]  # avoiding GOLD's ecosystem slot, with a controlled vocab

    sites.append(site)

# print(yaml_dumper.dumps(sites))
# Out:
# ABBY
# BARR
# BART
# BLAN
# BONA
# CLBJ
# CPER
# DCFS
# DEJU
# DELA
# DSNY
# GRSM
# GUAN
# HARV
# HEAL
# JERC
# JORN
# KONA
# KONZ
# LAJA
# LENO
# MLBS
# MOAB
# NIWO
# NOGP
# OAES
# ONAQ
# ORNL
# OSBS
# PUUM
# RMNP
# SCBI
# SERC
# SJER
# SOAP
# SRER
# STEI
# STER
# TALL
# TEAK
# TOOL
# TREE
# UKFS
# UNDE
# WOOD
# WREF
# YELL

# %%
# sample_class = "sls_soilCoreCollection_in.sampleID"
#
# unique_biosamples = sls_soilCoreCollection['sampleID'].unique()
# unique_biosamples.sort()
#
# # pprint.pprint(unique_biosamples)
#
# # https://data.neonscience.org/api/v0/samples/view?sampleTag=BART_004-M-3-28-20140819&sampleClass=sls_soilCoreCollection_in.sampleID
#
# url_base = "https://data.neonscience.org/api/v0/samples/view"
#
# biosamples = []
#
# for idx, i in enumerate(unique_biosamples[0:33]):
#     print(i)
#     url = f"{url_base}/{i}"
#     params = {
#         "sampleClass": sample_class,
#         "sampleTag": i,
#     }
#     response = requests.get(url_base, headers=headers, params=params).json()
#     pprint.pprint(response)
#     # site_id = f"nmdc:frsite-99-site{idx}"
#     # if 'data' not in response:
#     #     print("Skipping", i)
#     #     continue
#     # domain = FieldResearchSite(id=site_id, name=response['data']['locationName'],
#     #                            description=response['data']['locationDescription'])
#     # named_locations.append(domain)

# %%
cores_lod = sls_soilCoreCollection.to_dict(orient='records')

# %%
biosamples = []

# if we want to know the "exact" latitude and longitude of the core/biosamples
#   we would have to do arithmetic on the plot's latitude and longitude
#   and the core's offset (in meters?) from the plot (center?)

study_id = "nmdc:sty-99-neon"

for idx, i in enumerate(cores_lod):
    # print(i)

    if random.random() > 0.05:
        continue

    core_id = f"nmdc:bsm-99-{remove_unwanted_characters(i['sampleID'])}"
    print(core_id)
    location_id = f"nmdc:frsite-99-{remove_unwanted_characters(i['namedLocation'])}"
    core = Biosample(
        id=core_id,
        part_of=[study_id],
        env_broad_scale=ControlledIdentifiedTermValue(term=OntologyClass(id="ENVO:00000446", name="terrestrial biome")),
        env_local_scale=ControlledIdentifiedTermValue(term=OntologyClass(id="ENVO:01001886", name="landform")),
        env_medium=ControlledIdentifiedTermValue(term=OntologyClass(id="ENVO:00001998", name="soil")),
        collected_from=location_id,
        cur_vegetation=TextValue(has_raw_value=i["nlcdClass"]),
    )
    biosamples.append(core)
# print(yaml_dumper.dumps(biosamples))
# Out:
# nmdc:bsm-99-ABBY061M1330520161004
# nmdc:bsm-99-ABBY023O333420161005
# nmdc:bsm-99-ABBY062O1535520161005
# nmdc:bsm-99-ABBY003M26539520170511
# nmdc:bsm-99-ABBY063M112520170606
# nmdc:bsm-99-ABBY063M250520170606
# nmdc:bsm-99-ABBY063M451520171017
# nmdc:bsm-99-ABBY061M55820180419
# nmdc:bsm-99-ABBY061M751320180702
# nmdc:bsm-99-ABBY002M0320181022
# nmdc:bsm-99-ABBY070M16220181023
# nmdc:bsm-99-ABBY070M37220190417
# nmdc:bsm-99-ABBY023M283320190419
# nmdc:bsm-99-ABBY004M3552020190703
# nmdc:bsm-99-ABBY062M112520191024
# nmdc:bsm-99-ABBY070M352120200730
# nmdc:bsm-99-ABBY070O359520200730
# nmdc:bsm-99-ABBY062M352520200731
# nmdc:bsm-99-ABBY004O11420201026
# nmdc:bsm-99-ABBY002O283520201026
# nmdc:bsm-99-ABBY061M3151720201027
# nmdc:bsm-99-ABBY062O345620201028
# nmdc:bsm-99-ABBY001M2535520201028
# nmdc:bsm-99-ABBY001M265720210510
# nmdc:bsm-99-ABBY002M25220210719
# nmdc:bsm-99-ABBY006O2950520211018
# nmdc:bsm-99-BARR053O23220170808
# nmdc:bsm-99-BARR001O193120170809
# nmdc:bsm-99-BARR0023920200727OTHER
# nmdc:bsm-99-BARR0062120200727OTHER
# nmdc:bsm-99-BARR053O2257520210806
# nmdc:bsm-99-BARR004O1520210807
# nmdc:bsm-99-BART001M91720140619
# nmdc:bsm-99-BART028M233820140722
# nmdc:bsm-99-BART001O7020140722
# nmdc:bsm-99-BART032O393020140821
# nmdc:bsm-99-BART040O20530520150727
# nmdc:bsm-99-BART003O183520160425
# nmdc:bsm-99-BART042O3857520160426
# nmdc:bsm-99-BART001O352720160725
# nmdc:bsm-99-BART003O37536520161115
# nmdc:bsm-99-BART024O385420161115
# nmdc:bsm-99-BART003O27320170509
# nmdc:bsm-99-BART071O053420170613
# nmdc:bsm-99-BART036O3523520170613
# nmdc:bsm-99-BART042O52720170613
# nmdc:bsm-99-BART024O2251520170614
# nmdc:bsm-99-BART071O35920171004
# nmdc:bsm-99-BART071O62520171004
# nmdc:bsm-99-BART040O3351420180507
# nmdc:bsm-99-BART040O76520180508
# nmdc:bsm-99-BART005O21620181002
# nmdc:bsm-99-BART071O1658520190613
# nmdc:bsm-99-BART071O371820190613
# nmdc:bsm-99-BART042O415520200629
# nmdc:bsm-99-BART071O385620201004
# nmdc:bsm-99-BART023O365820201006
# nmdc:bsm-99-BART004O345320210504
# nmdc:bsm-99-BART071O115420210504
# nmdc:bsm-99-BART001O175220210609
# nmdc:bsm-99-BART003O3851520210610
# nmdc:bsm-99-BART023O1053520210610
# nmdc:bsm-99-BART005O2516520210611
# nmdc:bsm-99-BART005O3733520210611
# nmdc:bsm-99-BART005O5920211005
# nmdc:bsm-99-BLAN041M119520150714
# nmdc:bsm-99-BLAN005M351320150715
# nmdc:bsm-99-BLAN033M2052520151110
# nmdc:bsm-99-BLAN005M2953820160310
# nmdc:bsm-99-BLAN001M3915520160311
# nmdc:bsm-99-BLAN003M2053720160816
# nmdc:bsm-99-BLAN038M233220170313
# nmdc:bsm-99-BLAN001M279520170323
# nmdc:bsm-99-BLAN033M251420171005
# nmdc:bsm-99-BLAN003M3532520180312
# nmdc:bsm-99-BLAN002M3853020180312
# nmdc:bsm-99-BLAN031M2853620190312
# nmdc:bsm-99-BLAN005M1533520190313
# nmdc:bsm-99-BLAN005M39525520190313
# nmdc:bsm-99-BLAN004M355920190313
# nmdc:bsm-99-BLAN005M105720190701
# nmdc:bsm-99-BLAN007M35320190701
# nmdc:bsm-99-BLAN001M175320190701
# nmdc:bsm-99-BLAN033M2850520191016
# nmdc:bsm-99-BLAN0312320200406LOGISTICAL
# nmdc:bsm-99-BLAN007M151520201014
# nmdc:bsm-99-BLAN038M24531520210311
# nmdc:bsm-99-BLAN031M10420210714
# nmdc:bsm-99-BLAN033M732520211012
# nmdc:bsm-99-BONA001O292520170822
# nmdc:bsm-99-BONA009O39530520170823
# nmdc:bsm-99-BONA004O1053220180919
# nmdc:bsm-99-BONA001O2837520180920
# nmdc:bsm-99-BONA002O68520180920
# nmdc:bsm-99-BONA084O2059520190830
# nmdc:bsm-99-BONA084M1353420190830
# nmdc:bsm-99-BONA009O2524520190918
# nmdc:bsm-99-BONA084O510520190916
# nmdc:bsm-99-CLBJ040O163120160622
# nmdc:bsm-99-CLBJ032M32527520160623
# nmdc:bsm-99-CLBJ033O3551220160624
# nmdc:bsm-99-CLBJ006O2838520160817
# nmdc:bsm-99-CLBJ038O3353020160817
# nmdc:bsm-99-CLBJ033M285720170306
# nmdc:bsm-99-CLBJ040M113120170308
# nmdc:bsm-99-CLBJ003M322220170411
# nmdc:bsm-99-CLBJ038M31534520171109
# nmdc:bsm-99-CLBJ032M3656520180307
# nmdc:bsm-99-CLBJ002M90520180308
# nmdc:bsm-99-CLBJ003M28537520180308
# nmdc:bsm-99-CLBJ006M333020180410
# nmdc:bsm-99-CLBJ002M153020180410
# nmdc:bsm-99-CLBJ040M2525520180411
# nmdc:bsm-99-CLBJ040M224520181029
# nmdc:bsm-99-CLBJ040M215320181029
# nmdc:bsm-99-CLBJ006M7528520190325
# nmdc:bsm-99-CLBJ034M39520190305
# nmdc:bsm-99-CLBJ034M3452520190325
# nmdc:bsm-99-CLBJ032M3026520190325
# nmdc:bsm-99-CLBJ002M5524520190306
# nmdc:bsm-99-CLBJ003M3720190325
# nmdc:bsm-99-CLBJ032M2953820190429
# nmdc:bsm-99-CLBJ031M2159520190416
# nmdc:bsm-99-CLBJ031M382420190429
# nmdc:bsm-99-CLBJ040M38527520191125
# nmdc:bsm-99-CLBJ003M215120191104
# nmdc:bsm-99-CLBJ031M182520191105
# nmdc:bsm-99-CLBJ038M26020191105
# nmdc:bsm-99-CLBJ038M42020200303
# nmdc:bsm-99-CLBJ006M2525520201105
# nmdc:bsm-99-CLBJ003M3451420210324
# nmdc:bsm-99-CLBJ033M383520210505
# nmdc:bsm-99-CLBJ0312320210507MANAGEMENT
# nmdc:bsm-99-CLBJ001M3721520211109
# nmdc:bsm-99-CLBJ040M2256520211109
# nmdc:bsm-99-CLBJ033M3728520211109
# nmdc:bsm-99-CLBJ038M34520211110
# nmdc:bsm-99-CLBJ002M3123520211110
# nmdc:bsm-99-CPER003M193420130815
# nmdc:bsm-99-CPER001M15820130917
# nmdc:bsm-99-CPER002M362020131024
# nmdc:bsm-99-CPER004M31820131120
# nmdc:bsm-99-CPER002M312720131120
# nmdc:bsm-99-CPER004M372720131218
# nmdc:bsm-99-CPER003M40220140116
# nmdc:bsm-99-CPER004M163720140117
# nmdc:bsm-99-CPER002M91120140415
# nmdc:bsm-99-CPER004M283020140516
# nmdc:bsm-99-CPER002M9420140812
# nmdc:bsm-99-CPER004M233820140812
# nmdc:bsm-99-CPER004M143020141006
# nmdc:bsm-99-CPER003M164020141006
# nmdc:bsm-99-CPER002M512520160413
# nmdc:bsm-99-CPER006M315520160413
# nmdc:bsm-99-CPER045M333320160718
# nmdc:bsm-99-CPER001M34536520160720
# nmdc:bsm-99-CPER047M193620161114
# nmdc:bsm-99-CPER001M30517520161116
# nmdc:bsm-99-CPER006M35511520170403
# nmdc:bsm-99-CPER003M2956520170710
# nmdc:bsm-99-CPER047M351720170710
# nmdc:bsm-99-CPER048M34514520170710
# nmdc:bsm-99-CPER002M37528520180418
# nmdc:bsm-99-CPER002M511520180418
# nmdc:bsm-99-CPER002M1753320180702
# nmdc:bsm-99-CPER004M3851820180702
# nmdc:bsm-99-CPER045M811520180702
# nmdc:bsm-99-CPER048M2518520180702
# nmdc:bsm-99-CPER005M21530520180702
# nmdc:bsm-99-CPER001M335820181126
# nmdc:bsm-99-CPER045M3351420190416
# nmdc:bsm-99-CPER001M1053820190416
# nmdc:bsm-99-CPER048M8524520191105
# nmdc:bsm-99-CPER0014120200407LOGISTICAL
# nmdc:bsm-99-CPER047M3651220200623
# nmdc:bsm-99-CPER0044120200624LOGISTICAL
# nmdc:bsm-99-CPER047M331820201102
# nmdc:bsm-99-CPER045M3352920210412
# nmdc:bsm-99-CPER0052120210420LOGISTICAL
# nmdc:bsm-99-CPER003M154520210628
# nmdc:bsm-99-CPER003M154520210721
# nmdc:bsm-99-CPER0023920211025LOGISTICAL
# nmdc:bsm-99-CPER003M38530520211115
# nmdc:bsm-99-CPER004M72620211115
# nmdc:bsm-99-DCFS062M1358520170717
# nmdc:bsm-99-DCFS067M330520170717
# nmdc:bsm-99-DCFS007O2955520170718
# nmdc:bsm-99-DCFS006M3753720171017
# nmdc:bsm-99-DCFS007M2751520171017
# nmdc:bsm-99-DCFS003M304520171017
# nmdc:bsm-99-DCFS009M2431520180514
# nmdc:bsm-99-DCFS067M3137520180730
# nmdc:bsm-99-DCFS007M36519520180730
# nmdc:bsm-99-DCFS004M2653520180730
# nmdc:bsm-99-DCFS006M3429520180731
# nmdc:bsm-99-DCFS008M192520181016
# nmdc:bsm-99-DCFS007M3551520190501
# nmdc:bsm-99-DCFS004M373920190506
# nmdc:bsm-99-DCFS009M296520190528
# nmdc:bsm-99-DCFS008M245520190722
# nmdc:bsm-99-DCFS006M22534520190729
# nmdc:bsm-99-DCFS004M451520191029
# nmdc:bsm-99-DCFS008M2939520191003
# nmdc:bsm-99-DCFS065M412520191007
# nmdc:bsm-99-DCFS003M95320191029
# nmdc:bsm-99-DCFS063M026520191029
# nmdc:bsm-99-DCFS0032120200504LOGISTICAL
# nmdc:bsm-99-DCFS009M25120200730
# nmdc:bsm-99-DCFS003M853020200730
# nmdc:bsm-99-DCFS003M2538520200730
# nmdc:bsm-99-DCFS004M1138520211020
# nmdc:bsm-99-DEJU046O2053920160817
# nmdc:bsm-99-DEJU009O109520160818
# nmdc:bsm-99-DEJU002M1253120180619
# nmdc:bsm-99-DEJU045M3752820180621
# nmdc:bsm-99-DEJU045O753020180621
# nmdc:bsm-99-DEJU046O2520520180621
# nmdc:bsm-99-DEJU015O373020180709
# nmdc:bsm-99-DEJU045M753020180711
# nmdc:bsm-99-DEJU002O5420190626
# nmdc:bsm-99-DEJU002O16320200617
# nmdc:bsm-99-DEJU045O0510520210615
# nmdc:bsm-99-DELA002M4120160425
# nmdc:bsm-99-DELA038M24535520160824
# nmdc:bsm-99-DELA037M31620160824
# nmdc:bsm-99-DELA040M305620160824
# nmdc:bsm-99-DELA001M365820161026
# nmdc:bsm-99-DELA037M730520161026
# nmdc:bsm-99-DELA041M2334520181119
# nmdc:bsm-99-DELA005M3525520190513
# nmdc:bsm-99-DELA038M32511520190626
# nmdc:bsm-99-DELA002M85620190715
# nmdc:bsm-99-DELA001M32523520191112
# nmdc:bsm-99-DELA005M35220191113
# nmdc:bsm-99-DELA014M31520191113
# nmdc:bsm-99-DELA004M3533520191113
# nmdc:bsm-99-DELA041M32511520191202
# nmdc:bsm-99-DELA0402120200427LOGISTICAL
# nmdc:bsm-99-DELA014M1553120200715
# nmdc:bsm-99-DELA037M351720201103
# nmdc:bsm-99-DELA040M9620210428
# nmdc:bsm-99-DELA0402320210428LOCATIONFLOODED
# nmdc:bsm-99-DELA038M38920210429
# nmdc:bsm-99-DELA005M1256520211108
# nmdc:bsm-99-DELA037M3912520211110
# nmdc:bsm-99-DSNY021M362020130731
# nmdc:bsm-99-DSNY025M53520130731
# nmdc:bsm-99-DSNY009M92620130731
# nmdc:bsm-99-DSNY025M40620130731
# nmdc:bsm-99-DSNY021M354020130827
# nmdc:bsm-99-DSNY016M53520131114
# nmdc:bsm-99-DSNY025M372720131218
# nmdc:bsm-99-DSNY025M163720140122
# nmdc:bsm-99-DSNY009M21520140122
# nmdc:bsm-99-DSNY021M322820140327
# nmdc:bsm-99-DSNY025M283020140515
# nmdc:bsm-99-DSNY016M10320140611
# nmdc:bsm-99-DSNY005M33220140814
# nmdc:bsm-99-DSNY001M362420141022
# nmdc:bsm-99-DSNY016M133220141118
# nmdc:bsm-99-DSNY001M02120141217
# nmdc:bsm-99-DSNY043M7525520160712
# nmdc:bsm-99-DSNY043M125120160712
# nmdc:bsm-99-DSNY044M3835520160712
# nmdc:bsm-99-DSNY005M173020160712
# nmdc:bsm-99-DSNY043M52920161115
# nmdc:bsm-99-DSNY003O3221520170307
# nmdc:bsm-99-DSNY009M1332520170829
# nmdc:bsm-99-DSNY041M151520180307
# nmdc:bsm-99-DSNY001M213620180822
# nmdc:bsm-99-DSNY044M811520180904
# nmdc:bsm-99-DSNY009M3253620180905
# nmdc:bsm-99-DSNY043M251620190306
# nmdc:bsm-99-DSNY009M3020190826
# nmdc:bsm-99-DSNY009M8529520190826
# nmdc:bsm-99-DSNY009M36526520191022
# nmdc:bsm-99-DSNY043M14520200303
# nmdc:bsm-99-DSNY004M73120200303
# nmdc:bsm-99-DSNY006M83120200303
# nmdc:bsm-99-DSNY0412320200817LOGISTICAL
# nmdc:bsm-99-DSNY044M3230520201027
# nmdc:bsm-99-DSNY009M225520211019
# nmdc:bsm-99-DSNY003M71920211019
# nmdc:bsm-99-DSNY003M23120211019
# nmdc:bsm-99-GRSM016O163320150903
# nmdc:bsm-99-GRSM050O753720150903
# nmdc:bsm-99-GRSM003O10530520160426
# nmdc:bsm-99-GRSM060O2653820160426
# nmdc:bsm-99-GRSM055O312020161024
# nmdc:bsm-99-GRSM016O115720161025
# nmdc:bsm-99-GRSM002O81720170424
# nmdc:bsm-99-GRSM007O853220171018
# nmdc:bsm-99-GRSM007O732520180411
# nmdc:bsm-99-GRSM060O19538520180411
# nmdc:bsm-99-GRSM002O33534520181029
# nmdc:bsm-99-GRSM006M3451520190422
# nmdc:bsm-99-GRSM016O3550520191030
# nmdc:bsm-99-GRSM0033920200420LOGISTICAL
# nmdc:bsm-99-GRSM0554120200420LOGISTICAL
# nmdc:bsm-99-GRSM0023920200420LOGISTICAL
# nmdc:bsm-99-GRSM060M2051520200616
# nmdc:bsm-99-GRSM016O2459520200617
# nmdc:bsm-99-GRSM060M153920201103
# nmdc:bsm-99-GRSM006M1656520210426
# nmdc:bsm-99-GRSM002M26720210426
# nmdc:bsm-99-GRSM002M3335520210426
# nmdc:bsm-99-GRSM001M621520210426
# nmdc:bsm-99-GRSM058M355220210405
# nmdc:bsm-99-GRSM003M3751320210406
# nmdc:bsm-99-GRSM059M235520210406
# nmdc:bsm-99-GRSM007M110520210407
# nmdc:bsm-99-GRSM060M175720210629
# nmdc:bsm-99-GRSM003M293420210720
# nmdc:bsm-99-GRSM002O392120211108
# nmdc:bsm-99-GRSM055M052420211108
# nmdc:bsm-99-GUAN001O3952720150827
# nmdc:bsm-99-GUAN004O3631520150831
# nmdc:bsm-99-GUAN043M34525520160713
# nmdc:bsm-99-GUAN003M15220160715
# nmdc:bsm-99-GUAN003M18534520160928
# nmdc:bsm-99-GUAN049M652620161004
# nmdc:bsm-99-GUAN049M1052520170303
# nmdc:bsm-99-GUAN004M1456520170717
# nmdc:bsm-99-GUAN007M3518520170718
# nmdc:bsm-99-GUAN003M332620170718
# nmdc:bsm-99-GUAN048M19533520171107
# nmdc:bsm-99-GUAN048M2653220171107
# nmdc:bsm-99-GUAN004M27530520171219
# nmdc:bsm-99-GUAN001M7517520180703
# nmdc:bsm-99-GUAN003M3153720180703
# nmdc:bsm-99-GUAN048M8525520180717
# nmdc:bsm-99-GUAN048M33020180717
# nmdc:bsm-99-GUAN043M2731520180718
# nmdc:bsm-99-GUAN006M34539520180705
# nmdc:bsm-99-GUAN002M3812520180924
# nmdc:bsm-99-GUAN007M282520180925
# nmdc:bsm-99-GUAN049M303020181010
# nmdc:bsm-99-GUAN048M651820181010
# nmdc:bsm-99-GUAN007M452520190108
# nmdc:bsm-99-GUAN007M452520190128
# nmdc:bsm-99-GUAN006M1238520190108
# nmdc:bsm-99-GUAN048M275420190129
# nmdc:bsm-99-GUAN042M371020190109
# nmdc:bsm-99-GUAN042M6820190129
# nmdc:bsm-99-GUAN001M451520190716
# nmdc:bsm-99-GUAN007M251520190717
# nmdc:bsm-99-GUAN001M18539520200722
# nmdc:bsm-99-GUAN002M205220200831
# nmdc:bsm-99-GUAN043M53620200901
# nmdc:bsm-99-GUAN042M0519520200902
# nmdc:bsm-99-GUAN003M12220210119
# nmdc:bsm-99-GUAN043M25520210120
# nmdc:bsm-99-GUAN0492320210727LOGISTICAL
# nmdc:bsm-99-GUAN048M156520210920
# nmdc:bsm-99-GUAN004M051920210922
# nmdc:bsm-99-GUAN003M753220210922
# nmdc:bsm-99-HARV004O343720130709
# nmdc:bsm-99-HARV016O31920130807
# nmdc:bsm-99-HARV004M342920130911
# nmdc:bsm-99-HARV013M293720140514
# nmdc:bsm-99-HARV001O223220140715
# nmdc:bsm-99-HARV021O361620140717
# nmdc:bsm-99-HARV013O01320140812
# nmdc:bsm-99-HARV020O302720140812
# nmdc:bsm-99-HARV013M344020141014
# nmdc:bsm-99-HARV004M8820141014
# nmdc:bsm-99-HARV020O263520141014
# nmdc:bsm-99-HARV037M11536520150818
# nmdc:bsm-99-HARV020O3457520160308
# nmdc:bsm-99-HARV034O36537520160802
# nmdc:bsm-99-HARV033O2232520161205
# nmdc:bsm-99-HARV001O12620161205
# nmdc:bsm-99-HARV020O6420161206
# nmdc:bsm-99-HARV002O263720161206
# nmdc:bsm-99-HARV002O39720170426
# nmdc:bsm-99-HARV001O73220170731
# nmdc:bsm-99-HARV037O22537520170731
# nmdc:bsm-99-HARV002O3525520170801
# nmdc:bsm-99-HARV034O1353620171024
# nmdc:bsm-99-HARV033M145020180418
# nmdc:bsm-99-HARV013M3030520180418
# nmdc:bsm-99-HARV004O3630520180418
# nmdc:bsm-99-HARV021O285120180507
# nmdc:bsm-99-HARV035M255920180509
# nmdc:bsm-99-HARV035O3833520180709
# nmdc:bsm-99-HARV005O113720180711
# nmdc:bsm-99-HARV005M2453620180711
# nmdc:bsm-99-HARV013M252520180712
# nmdc:bsm-99-HARV021O65220180730
# nmdc:bsm-99-HARV021M3818520180712
# nmdc:bsm-99-HARV005M2356520181029
# nmdc:bsm-99-HARV002M122520181029
# nmdc:bsm-99-HARV004M61020181009
# nmdc:bsm-99-HARV034M3451120181030
# nmdc:bsm-99-HARV021M12820181010
# nmdc:bsm-99-HARV021O31420181029
# nmdc:bsm-99-HARV037O3319520181010
# nmdc:bsm-99-HARV004O1153320190422
# nmdc:bsm-99-HARV005O3056520190423
# nmdc:bsm-99-HARV037O2953320190715
# nmdc:bsm-99-HARV005O103920190716
# nmdc:bsm-99-HARV002O9820190716
# nmdc:bsm-99-HARV013O42020191008
# nmdc:bsm-99-HARV001O955520191008
# nmdc:bsm-99-HARV034O2353120191010
# nmdc:bsm-99-HARV037O38320200713
# nmdc:bsm-99-HARV033O4524520200715
# nmdc:bsm-99-HARV002O39525520201011
# nmdc:bsm-99-HARV037O152320210420
# nmdc:bsm-99-HARV002O051620210422
# nmdc:bsm-99-HARV005O2820210422
# nmdc:bsm-99-HARV001O63820210707
# nmdc:bsm-99-HARV005O81020210708
# nmdc:bsm-99-HARV037O4420211011
# nmdc:bsm-99-HARV034O053520211011
# nmdc:bsm-99-HEAL047M77520150826
# nmdc:bsm-99-HEAL046O313820160726
# nmdc:bsm-99-HEAL046O853120170725
# nmdc:bsm-99-HEAL011O143320170726
# nmdc:bsm-99-HEAL011O2653820180717
# nmdc:bsm-99-HEAL048O21620190710
# nmdc:bsm-99-HEAL005O11820200727
# nmdc:bsm-99-HEAL047O3211520200728
# nmdc:bsm-99-HEAL046O85720210622
# nmdc:bsm-99-HEAL025O651620210624
# nmdc:bsm-99-HEAL011M3453820210625
# nmdc:bsm-99-HEAL047O3036520210712
# nmdc:bsm-99-JERC002M72920140611
# nmdc:bsm-99-JERC001M24720140611
# nmdc:bsm-99-JERC006M16720140910
# nmdc:bsm-99-JERC006M372220141006
# nmdc:bsm-99-JERC049M752120160426
# nmdc:bsm-99-JERC003M196520160726
# nmdc:bsm-99-JERC003M2136520160726
# nmdc:bsm-99-JERC006M712520160726
# nmdc:bsm-99-JERC002M3051320160726
# nmdc:bsm-99-JERC047M3415520161011
# nmdc:bsm-99-JERC001M1053920170411
# nmdc:bsm-99-JERC004M1351520170411
# nmdc:bsm-99-JERC006M63420170724
# nmdc:bsm-99-JERC050M31720170725
# nmdc:bsm-99-JERC049M19720170725
# nmdc:bsm-99-JERC001M233520171107
# nmdc:bsm-99-JERC003M133520171107
# nmdc:bsm-99-JERC047M7820171107
# nmdc:bsm-99-JERC006M32529520171107
# nmdc:bsm-99-JERC006M8529520180403
# nmdc:bsm-99-JERC001M851020180723
# nmdc:bsm-99-JERC006M43320180724
# nmdc:bsm-99-JERC049M759520181106
# nmdc:bsm-99-JERC003M361220190319
# nmdc:bsm-99-JERC001M1953220190319
# nmdc:bsm-99-JERC002M1353120190730
# nmdc:bsm-99-JERC049M951220191118
# nmdc:bsm-99-JERC049M452420191104
# nmdc:bsm-99-JERC005M1453220191118
# nmdc:bsm-99-JERC0493920200323LOGISTICAL
# nmdc:bsm-99-JERC0032120200323LOGISTICAL
# nmdc:bsm-99-JERC0053920200323LOGISTICAL
# nmdc:bsm-99-JERC0473920200727LOGISTICAL
# nmdc:bsm-99-JERC001M163520210412
# nmdc:bsm-99-JERC005M3622520210412
# nmdc:bsm-99-JERC048M29532520210413
# nmdc:bsm-99-JERC049M305920210413
# nmdc:bsm-99-JERC048M369520210720
# nmdc:bsm-99-JERC001M375120210721
# nmdc:bsm-99-JERC050M3923520211102
# nmdc:bsm-99-JERC006M32522520211102
# nmdc:bsm-99-JORN001M3150520150626
# nmdc:bsm-99-JORN047M1553520150626
# nmdc:bsm-99-JORN047M36516520150626
# nmdc:bsm-99-JORN003M3453120150728
# nmdc:bsm-99-JORN044M753520150729
# nmdc:bsm-99-JORN004M03520160621
# nmdc:bsm-99-JORN001M273420160621
# nmdc:bsm-99-JORN045M3016520160719
# nmdc:bsm-99-JORN045M453520170627
# nmdc:bsm-99-JORN003M22720170808
# nmdc:bsm-99-JORN001M2138520170808
# nmdc:bsm-99-JORN001M2138520170829
# nmdc:bsm-99-JORN047M361320171114
# nmdc:bsm-99-JORN042M371220171114
# nmdc:bsm-99-JORN042M375120180626
# nmdc:bsm-99-JORN001M33528520180626
# nmdc:bsm-99-JORN045M851820180626
# nmdc:bsm-99-JORN004M651120180807
# nmdc:bsm-99-JORN003M3538520180807
# nmdc:bsm-99-JORN001M3814520181023
# nmdc:bsm-99-JORN005M1153820181023
# nmdc:bsm-99-JORN005M52320190618
# nmdc:bsm-99-JORN004M382620190618
# nmdc:bsm-99-JORN001M206520190618
# nmdc:bsm-99-JORN005M1138520190820
# nmdc:bsm-99-JORN044M3524520191022
# nmdc:bsm-99-JORN047M3113520191022
# nmdc:bsm-99-JORN0422320200713LOGISTICAL
# nmdc:bsm-99-JORN0053920200713LOGISTICAL
# nmdc:bsm-99-JORN0023920200817LOGISTICAL
# nmdc:bsm-99-JORN0034120200817LOGISTICAL
# nmdc:bsm-99-JORN0044120200817LOGISTICAL
# nmdc:bsm-99-JORN0023920201116LOGISTICAL
# nmdc:bsm-99-JORN0422120201116LOGISTICAL
# nmdc:bsm-99-JORN0034120201116LOGISTICAL
# nmdc:bsm-99-JORN044M3536520210714
# nmdc:bsm-99-JORN002M153820210714
# nmdc:bsm-99-JORN002M3152620210714
# nmdc:bsm-99-JORN047M362220210714
# nmdc:bsm-99-JORN045M3953520211026
# nmdc:bsm-99-KONA004M2453420170808
# nmdc:bsm-99-KONA048M935520170809
# nmdc:bsm-99-KONA005M35420171018
# nmdc:bsm-99-KONA048M245020180416
# nmdc:bsm-99-KONA002M35220180416
# nmdc:bsm-99-KONA005M223920180417
# nmdc:bsm-99-KONA048M30517520180730
# nmdc:bsm-99-KONA005M3536520180731
# nmdc:bsm-99-KONA048M5620181022
# nmdc:bsm-99-KONA048M2753220181022
# nmdc:bsm-99-KONA006M215520190415
# nmdc:bsm-99-KONA002M8120190617
# nmdc:bsm-99-KONA002M33511520190617
# nmdc:bsm-99-KONA002M38535520190709
# nmdc:bsm-99-KONA048M718520190709
# nmdc:bsm-99-KONA001M1631520190709
# nmdc:bsm-99-KONA004M32020190708
# nmdc:bsm-99-KONA005M223220191007
# nmdc:bsm-99-KONA003M1453520191028
# nmdc:bsm-99-KONA001M3152020191029
# nmdc:bsm-99-KONA048M309520191008
# nmdc:bsm-99-KONA054M3152220200707
# nmdc:bsm-99-KONA059M25536520200929
# nmdc:bsm-99-KONA004M1230520210415
# nmdc:bsm-99-KONA005M336520210628
# nmdc:bsm-99-KONA004M32527520210628
# nmdc:bsm-99-KONA048M313520210629
# nmdc:bsm-99-KONA059M3428520210629
# nmdc:bsm-99-KONA054M7516520211012
# nmdc:bsm-99-KONZ001M34537520150819
# nmdc:bsm-99-KONZ024M228520150824
# nmdc:bsm-99-KONZ002M551520160425
# nmdc:bsm-99-KONZ002M15920160712
# nmdc:bsm-99-KONZ046M3723520161024
# nmdc:bsm-99-KONZ046M833520161024
# nmdc:bsm-99-KONZ024M233620170502
# nmdc:bsm-99-KONZ001M3350520170710
# nmdc:bsm-99-KONZ005M22620170731
# nmdc:bsm-99-KONZ043M62620170711
# nmdc:bsm-99-KONZ042M28533520170712
# nmdc:bsm-99-KONZ043M62620170801
# nmdc:bsm-99-KONZ045M3052120170801
# nmdc:bsm-99-KONZ043M213820171003
# nmdc:bsm-99-KONZ001M385720180424
# nmdc:bsm-99-KONZ024M33720180716
# nmdc:bsm-99-KONZ043M433520181009
# nmdc:bsm-99-KONZ003M37522520190409
# nmdc:bsm-99-KONZ043M39533520190415
# nmdc:bsm-99-KONZ043M21620190415
# nmdc:bsm-99-KONZ024M10533520190715
# nmdc:bsm-99-KONZ0452120200427LOGISTICAL
# nmdc:bsm-99-KONZ0244120200427LOGISTICAL
# nmdc:bsm-99-KONZ042M3152520201006
# nmdc:bsm-99-KONZ042M139520201006
# nmdc:bsm-99-KONZ024M3051420210423
# nmdc:bsm-99-KONZ001M3253920210720
# nmdc:bsm-99-KONZ003M15920211018
# nmdc:bsm-99-LAJA042M185120160810
# nmdc:bsm-99-LAJA051M30533520160810
# nmdc:bsm-99-LAJA002M71320160912
# nmdc:bsm-99-LAJA001M3430520160920
# nmdc:bsm-99-LAJA046M652420170307
# nmdc:bsm-99-LAJA002M2519520171115
# nmdc:bsm-99-LAJA015M825520180219
# nmdc:bsm-99-LAJA001M243720180220
# nmdc:bsm-99-LAJA042M361920180221
# nmdc:bsm-99-LAJA046M613520181023
# nmdc:bsm-99-LAJA015M512520181025
# nmdc:bsm-99-LAJA046M27535520200217
# nmdc:bsm-99-LAJA042M8520520200713
# nmdc:bsm-99-LAJA044M255920200714
# nmdc:bsm-99-LAJA046M49520200728
# nmdc:bsm-99-LAJA003M14520200715
# nmdc:bsm-99-LAJA015M6620200729
# nmdc:bsm-99-LAJA046M5531520201014
# nmdc:bsm-99-LAJA046M28537520201014
# nmdc:bsm-99-LAJA046M9220201215
# nmdc:bsm-99-LAJA042M9513520210104
# nmdc:bsm-99-LAJA042M723520210104
# nmdc:bsm-99-LAJA015M35521520210105
# nmdc:bsm-99-LAJA0012320210712LOGISTICAL
# nmdc:bsm-99-LAJA002M158520210713
# nmdc:bsm-99-LAJA0463920211025LOGISTICAL
# nmdc:bsm-99-LAJA002M11539520211222
# nmdc:bsm-99-LAJA004M1353920211222
# nmdc:bsm-99-LENO063M950520160829
# nmdc:bsm-99-LENO003M2033520160829
# nmdc:bsm-99-LENO005M116520160830
# nmdc:bsm-99-LENO005M3435520160830
# nmdc:bsm-99-LENO062M552120160830
# nmdc:bsm-99-LENO006M35521520160830
# nmdc:bsm-99-LENO064M81920180425
# nmdc:bsm-99-LENO063M18220180425
# nmdc:bsm-99-LENO061M35517520180425
# nmdc:bsm-99-LENO004M343720180514
# nmdc:bsm-99-LENO003M353620180514
# nmdc:bsm-99-LENO002M25520180514
# nmdc:bsm-99-LENO064M152320180514
# nmdc:bsm-99-LENO002M2053220180731
# nmdc:bsm-99-LENO062M1512520180731
# nmdc:bsm-99-LENO006M1955520180709
# nmdc:bsm-99-LENO005M28120181128
# nmdc:bsm-99-LENO006M123220181108
# nmdc:bsm-99-LENO061M361520190521
# nmdc:bsm-99-LENO006M3655520190521
# nmdc:bsm-99-LENO062M23535520191119
# nmdc:bsm-99-LENO063M651020191119
# nmdc:bsm-99-LENO003M11530520191120
# nmdc:bsm-99-LENO003M157520191120
# nmdc:bsm-99-LENO063M36512520200721
# nmdc:bsm-99-LENO0044120201118LOGISTICAL
# nmdc:bsm-99-LENO063M23220210506
# nmdc:bsm-99-MLBS005O0518520171108
# nmdc:bsm-99-MLBS001O273220180424
# nmdc:bsm-99-MLBS061M53120180425
# nmdc:bsm-99-MLBS002O221520180514
# nmdc:bsm-99-MLBS001O323720180611
# nmdc:bsm-99-MLBS061M326520180703
# nmdc:bsm-99-MLBS063M361220180703
# nmdc:bsm-99-MLBS063O29532520180703
# nmdc:bsm-99-MLBS005M26620181009
# nmdc:bsm-99-MLBS003M2155520181029
# nmdc:bsm-99-MLBS063O1239520181029
# nmdc:bsm-99-MLBS003M293820190821
# nmdc:bsm-99-MLBS007M1053520191007
# nmdc:bsm-99-MLBS001M255720191009
# nmdc:bsm-99-MLBS0074120200504LOGISTICAL
# nmdc:bsm-99-MLBS0674120200504LOGISTICAL
# nmdc:bsm-99-MLBS001M34720200715
# nmdc:bsm-99-MLBS002O3651620201020
# nmdc:bsm-99-MLBS061O434520210511
# nmdc:bsm-99-MLBS003M285820210727
# nmdc:bsm-99-MLBS001M275520211005
# nmdc:bsm-99-MLBS001M1356520211005
# nmdc:bsm-99-MOAB004M5530520150731
# nmdc:bsm-99-MOAB047M30620150802
# nmdc:bsm-99-MOAB002M61420160317
# nmdc:bsm-99-MOAB006M3852620160318
# nmdc:bsm-99-MOAB001M652020160727
# nmdc:bsm-99-MOAB045M351820161114
# nmdc:bsm-99-MOAB046M3536520161115
# nmdc:bsm-99-MOAB004M14539520170327
# nmdc:bsm-99-MOAB045M92720170411
# nmdc:bsm-99-MOAB006M81420170411
# nmdc:bsm-99-MOAB004M285020170521
# nmdc:bsm-99-MOAB005M41520170522
# nmdc:bsm-99-MOAB005M2659520170522
# nmdc:bsm-99-MOAB045M3751820170523
# nmdc:bsm-99-MOAB047M2133520170523
# nmdc:bsm-99-MOAB005M637520170619
# nmdc:bsm-99-MOAB047M375120170620
# nmdc:bsm-99-MOAB004M3021520171023
# nmdc:bsm-99-MOAB001M273820171004
# nmdc:bsm-99-MOAB003M5510520180604
# nmdc:bsm-99-MOAB002M345320180604
# nmdc:bsm-99-MOAB004M92820180605
# nmdc:bsm-99-MOAB046M2654520180605
# nmdc:bsm-99-MOAB001M13020190402
# nmdc:bsm-99-MOAB046M427520190403
# nmdc:bsm-99-MOAB005M1053620200317
# nmdc:bsm-99-MOAB006M341720200317
# nmdc:bsm-99-MOAB0462120201110LOGISTICAL
# nmdc:bsm-99-NIWO041M83820150727
# nmdc:bsm-99-NIWO040O01720150729
# nmdc:bsm-99-NIWO001O8522520150729
# nmdc:bsm-99-NIWO041M11320161010
# nmdc:bsm-99-NIWO004M3953820161011
# nmdc:bsm-99-NIWO002O175920170905
# nmdc:bsm-99-NIWO040O2434520170907
# nmdc:bsm-99-NIWO043M222520180618
# nmdc:bsm-99-NIWO041M32020180620
# nmdc:bsm-99-NIWO005O8120180620
# nmdc:bsm-99-NIWO002O204520180731
# nmdc:bsm-99-NIWO041O351320180731
# nmdc:bsm-99-NIWO005O32514520180918
# nmdc:bsm-99-NIWO001O2933520180920
# nmdc:bsm-99-NIWO002O79520190619
# nmdc:bsm-99-NIWO001M6528520190619
# nmdc:bsm-99-NIWO005M1250520190731
# nmdc:bsm-99-NIWO006M223620190819
# nmdc:bsm-99-NIWO043M2753520190826
# nmdc:bsm-99-NIWO040M376520190826
# nmdc:bsm-99-NIWO001M3027520190826
# nmdc:bsm-99-NIWO001M152820190903
# nmdc:bsm-99-NIWO041M36920190909
# nmdc:bsm-99-NIWO005O3053520190909
# nmdc:bsm-99-NIWO003M2831520191001
# nmdc:bsm-99-NIWO043M253620191007
# nmdc:bsm-99-NIWO0052320200608LOGISTICAL
# nmdc:bsm-99-NIWO0022120200608LOGISTICAL
# nmdc:bsm-99-NIWO042O313120200706
# nmdc:bsm-99-NIWO003M3913520210614
# nmdc:bsm-99-NIWO001O195920210728
# nmdc:bsm-99-NIWO0034120210920LOGISTICAL
# nmdc:bsm-99-NIWO0032320210920LOGISTICAL
# nmdc:bsm-99-NOGP064M4515520160718
# nmdc:bsm-99-NOGP062M1353120160718
# nmdc:bsm-99-NOGP001M0527520160720
# nmdc:bsm-99-NOGP062M3115520170418
# nmdc:bsm-99-NOGP002M1437520180426
# nmdc:bsm-99-NOGP002M284520180426
# nmdc:bsm-99-NOGP005M35120180702
# nmdc:bsm-99-NOGP003M22420180703
# nmdc:bsm-99-NOGP005M175120180926
# nmdc:bsm-99-NOGP061M51320190708
# nmdc:bsm-99-NOGP002M385620190709
# nmdc:bsm-99-NOGP012M1753620191016
# nmdc:bsm-99-NOGP0012320200415LOGISTICAL
# nmdc:bsm-99-NOGP001M28420200701
# nmdc:bsm-99-NOGP064M36514520200723
# nmdc:bsm-99-NOGP061M365220200708
# nmdc:bsm-99-NOGP0624120201005LOGISTICAL
# nmdc:bsm-99-NOGP064O519520210420
# nmdc:bsm-99-NOGP064M395620210420
# nmdc:bsm-99-NOGP061M3534520210420
# nmdc:bsm-99-NOGP062M27539520210420
# nmdc:bsm-99-NOGP001M353120210421
# nmdc:bsm-99-NOGP012M113520210421
# nmdc:bsm-99-NOGP006M9020210720
# nmdc:bsm-99-NOGP061M1453220210720
# nmdc:bsm-99-NOGP064O21535520211011
# nmdc:bsm-99-OAES001M6520520150728
# nmdc:bsm-99-OAES012M385520150729
# nmdc:bsm-99-OAES012M852820150729
# nmdc:bsm-99-OAES011M953620150729
# nmdc:bsm-99-OAES009M11320160614
# nmdc:bsm-99-OAES003M303620160614
# nmdc:bsm-99-OAES044M2237520160615
# nmdc:bsm-99-OAES002M1537520160810
# nmdc:bsm-99-OAES044M312620160919
# nmdc:bsm-99-OAES044M225920160919
# nmdc:bsm-99-OAES004M053320170404
# nmdc:bsm-99-OAES001M1253520170626
# nmdc:bsm-99-OAES043M953020170627
# nmdc:bsm-99-OAES044M053820180403
# nmdc:bsm-99-OAES043M23520180403
# nmdc:bsm-99-OAES042M43320180424
# nmdc:bsm-99-OAES003M410520180424
# nmdc:bsm-99-OAES002M22536520180404
# nmdc:bsm-99-OAES002M22536520180424
# nmdc:bsm-99-OAES007M23530520180530
# nmdc:bsm-99-OAES002M278520180530
# nmdc:bsm-99-OAES045M3116520181105
# nmdc:bsm-99-OAES009M383020181105
# nmdc:bsm-99-OAES042M93420190402
# nmdc:bsm-99-OAES002M12537520190402
# nmdc:bsm-99-OAES044M352720190402
# nmdc:bsm-99-OAES044M3259520190806
# nmdc:bsm-99-OAES043M4535520190806
# nmdc:bsm-99-OAES042M3551820190806
# nmdc:bsm-99-OAES043M393520200310
# nmdc:bsm-99-OAES0072120200504LOGISTICAL
# nmdc:bsm-99-OAES0032120200504LOGISTICAL
# nmdc:bsm-99-OAES0014120200504LOGISTICAL
# nmdc:bsm-99-OAES0453920210301LOGISTICAL
# nmdc:bsm-99-OAES044M75320210816
# nmdc:bsm-99-OAES043M34920210816
# nmdc:bsm-99-OAES009M227520210817
# nmdc:bsm-99-ONAQ008M35120160406
# nmdc:bsm-99-ONAQ005M15820160408
# nmdc:bsm-99-ONAQ003M1953920160725
# nmdc:bsm-99-ONAQ005M3152920161110
# nmdc:bsm-99-ONAQ003M39528520170406
# nmdc:bsm-99-ONAQ042M19320170629
# nmdc:bsm-99-ONAQ042M353620180319
# nmdc:bsm-99-ONAQ010M11720180320
# nmdc:bsm-99-ONAQ010M3613520180320
# nmdc:bsm-99-ONAQ041M652720180530
# nmdc:bsm-99-ONAQ044M810520190327
# nmdc:bsm-99-ONAQ005M23530520190617
# nmdc:bsm-99-ONAQ003M3058520191022
# nmdc:bsm-99-ONAQ008M118520191022
# nmdc:bsm-99-ONAQ0084120200323LOGISTICAL
# nmdc:bsm-99-ONAQ008M326520200711
# nmdc:bsm-99-ONAQ043M834520200713
# nmdc:bsm-99-ONAQ0052320201028LOGISTICAL
# nmdc:bsm-99-ONAQ041M31517520210329
# nmdc:bsm-99-ONAQ008M25534520210330
# nmdc:bsm-99-ONAQ003M3830520210418
# nmdc:bsm-99-ONAQ003M273220210616
# nmdc:bsm-99-ONAQ0042320211021LOGISTICAL
# nmdc:bsm-99-ONAQ044M620520211021
# nmdc:bsm-99-ONAQ0054120211022LOGISTICAL
# nmdc:bsm-99-ONAQ041M038520211109
# nmdc:bsm-99-ONAQ043M17620211111
# nmdc:bsm-99-ORNL037M42320140715
# nmdc:bsm-99-ORNL021M143020140908
# nmdc:bsm-99-ORNL001O3150520150812
# nmdc:bsm-99-ORNL049O24531520150814
# nmdc:bsm-99-ORNL049M1134520150814
# nmdc:bsm-99-ORNL021O9120160229
# nmdc:bsm-99-ORNL029O2157520160727
# nmdc:bsm-99-ORNL021M16520170427
# nmdc:bsm-99-ORNL021M203520170404
# nmdc:bsm-99-ORNL021M183520170427
# nmdc:bsm-99-ORNL003O313420170404
# nmdc:bsm-99-ORNL003M313420170427
# nmdc:bsm-99-ORNL001O3053320170427
# nmdc:bsm-99-ORNL029M851820170427
# nmdc:bsm-99-ORNL053M1754520170406
# nmdc:bsm-99-ORNL049O133620170406
# nmdc:bsm-99-ORNL021O393720170619
# nmdc:bsm-99-ORNL046M371120170621
# nmdc:bsm-99-ORNL046O1258520170621
# nmdc:bsm-99-ORNL001O37513520170706
# nmdc:bsm-99-ORNL049O183420170706
# nmdc:bsm-99-ORNL049O3512520170706
# nmdc:bsm-99-ORNL053M837520170706
# nmdc:bsm-99-ORNL043M3151520171026
# nmdc:bsm-99-ORNL001O36523520171113
# nmdc:bsm-99-ORNL003O11536520171113
# nmdc:bsm-99-ORNL049O3814520171115
# nmdc:bsm-99-ORNL043O373320181022
# nmdc:bsm-99-ORNL002O1751520181024
# nmdc:bsm-99-ORNL002M651820191104
# nmdc:bsm-99-ORNL003M751620191104
# nmdc:bsm-99-ORNL004M1038520191105
# nmdc:bsm-99-ORNL0273920200408LOGISTICAL
# nmdc:bsm-99-ORNL0012320200408LOGISTICAL
# nmdc:bsm-99-ORNL002M3434520200603
# nmdc:bsm-99-ORNL003M183520200603
# nmdc:bsm-99-ORNL006M285020200603
# nmdc:bsm-99-ORNL006M15520201030
# nmdc:bsm-99-ORNL004M3059520210322
# nmdc:bsm-99-ORNL003M026520210324
# nmdc:bsm-99-ORNL053M225620210706
# nmdc:bsm-99-ORNL006M27536520210708
# nmdc:bsm-99-OSBS002M31820130919
# nmdc:bsm-99-OSBS003M383820130919
# nmdc:bsm-99-OSBS006M30820130920
# nmdc:bsm-99-OSBS006M342920131112
# nmdc:bsm-99-OSBS003M28820131211
# nmdc:bsm-99-OSBS002M21320131211
# nmdc:bsm-99-OSBS002M382420131211
# nmdc:bsm-99-OSBS003M353720140314
# nmdc:bsm-99-OSBS003M203820140603
# nmdc:bsm-99-OSBS001M29220140701
# nmdc:bsm-99-OSBS004M4920140813
# nmdc:bsm-99-OSBS025M303820140818
# nmdc:bsm-99-OSBS002M103420140917
# nmdc:bsm-99-OSBS003M28320141030
# nmdc:bsm-99-OSBS029M321520160418
# nmdc:bsm-99-OSBS026M21820160418
# nmdc:bsm-99-OSBS029M1537520161004
# nmdc:bsm-99-OSBS003M2353720170406
# nmdc:bsm-99-OSBS022O7531520170406
# nmdc:bsm-99-OSBS001O39120170712
# nmdc:bsm-99-OSBS003M4537520171023
# nmdc:bsm-99-OSBS001M122520171024
# nmdc:bsm-99-OSBS029M11520171025
# nmdc:bsm-99-OSBS023M16120180321
# nmdc:bsm-99-OSBS029M28533520181029
# nmdc:bsm-99-OSBS031M65620190701
# nmdc:bsm-99-OSBS0053920200330LOGISTICAL
# nmdc:bsm-99-OSBS0022320200330LOGISTICAL
# nmdc:bsm-99-OSBS026M286520200708
# nmdc:bsm-99-OSBS029M102520201012
# nmdc:bsm-99-OSBS004M26620201012
# nmdc:bsm-99-OSBS005M3157520201013
# nmdc:bsm-99-OSBS003M15720210331
# nmdc:bsm-99-OSBS027M2153720210706
# nmdc:bsm-99-OSBS005O551120210708
# nmdc:bsm-99-OSBS029M622520211011
# nmdc:bsm-99-OSBS027M312420211011
# nmdc:bsm-99-OSBS031M557520211025
# nmdc:bsm-99-OSBS003O39510520211013
# nmdc:bsm-99-OSBS063M3916520211013
# nmdc:bsm-99-OSBS004M3451620211027
# nmdc:bsm-99-OSBS005O321220211013
# nmdc:bsm-99-OSBS001O3835520211015
# nmdc:bsm-99-OSBS001M23320211104
# nmdc:bsm-99-PUUM032O453820181110
# nmdc:bsm-99-PUUM031M352220190121
# nmdc:bsm-99-PUUM006M352820190107
# nmdc:bsm-99-PUUM007O55120190122
# nmdc:bsm-99-PUUM010O31920190109
# nmdc:bsm-99-PUUM004M361220190109
# nmdc:bsm-99-PUUM006M630520190624
# nmdc:bsm-99-PUUM006O31512520190624
# nmdc:bsm-99-PUUM015M332620190611
# nmdc:bsm-99-PUUM004M33120190611
# nmdc:bsm-99-PUUM014O3127520190612
# nmdc:bsm-99-PUUM036O3917520191104
# nmdc:bsm-99-PUUM036O33720200113
# nmdc:bsm-99-PUUM040O3713520200113
# nmdc:bsm-99-PUUM014O183020200617
# nmdc:bsm-99-PUUM010O3353620200623
# nmdc:bsm-99-PUUM036O2139520201102
# nmdc:bsm-99-PUUM007O1653520210106
# nmdc:bsm-99-PUUM006O1351520210602
# nmdc:bsm-99-PUUM042O951220211129
# nmdc:bsm-99-PUUM007O325020211201
# nmdc:bsm-99-RMNP045O213920170807
# nmdc:bsm-99-RMNP002O759520171002
# nmdc:bsm-99-RMNP002O17620180529
# nmdc:bsm-99-RMNP013O3753620180529
# nmdc:bsm-99-RMNP043O3052520180723
# nmdc:bsm-99-RMNP045O20420181024
# nmdc:bsm-99-RMNP005O305020190531
# nmdc:bsm-99-RMNP006O33920190722
# nmdc:bsm-99-RMNP044M3251320190919
# nmdc:bsm-99-RMNP045M46520190919
# nmdc:bsm-99-RMNP0062320200520LOGISTICAL
# nmdc:bsm-99-RMNP0063920200629LOGISTICAL
# nmdc:bsm-99-RMNP0193920200629LOGISTICAL
# nmdc:bsm-99-RMNP013O3237520200720
# nmdc:bsm-99-RMNP0452120200930LOGISTICAL
# nmdc:bsm-99-RMNP004O2231520201001
# nmdc:bsm-99-RMNP002M19920201117
# nmdc:bsm-99-RMNP002M22533520201117
# nmdc:bsm-99-RMNP004M2231520201117
# nmdc:bsm-99-RMNP019M551720201117
# nmdc:bsm-99-RMNP0062120210524LOCATIONSNOWCOVERED
# nmdc:bsm-99-RMNP013O132520210524
# nmdc:bsm-99-RMNP005O273620210526
# nmdc:bsm-99-RMNP005O124520210526
# nmdc:bsm-99-RMNP045M362520210623
# nmdc:bsm-99-RMNP013M35420211004
# nmdc:bsm-99-RMNP043M95520211006
# nmdc:bsm-99-SCBI045M303820140825
# nmdc:bsm-99-SCBI004M244020140825
# nmdc:bsm-99-SCBI003M32820140915
# nmdc:bsm-99-SCBI002M382320141013
# nmdc:bsm-99-SCBI006M164020141013
# nmdc:bsm-99-SCBI003M33536520150803
# nmdc:bsm-99-SCBI049M89520151112
# nmdc:bsm-99-SCBI045M382120151112
# nmdc:bsm-99-SCBI003M3453120151113
# nmdc:bsm-99-SCBI006M93520151113
# nmdc:bsm-99-SCBI047M253120160314
# nmdc:bsm-99-SCBI006M319520160317
# nmdc:bsm-99-SCBI047M3853920160803
# nmdc:bsm-99-SCBI045M91620160804
# nmdc:bsm-99-SCBI003M310520161019
# nmdc:bsm-99-SCBI049M36536520161020
# nmdc:bsm-99-SCBI012M343820161021
# nmdc:bsm-99-SCBI005M36531520170424
# nmdc:bsm-99-SCBI005M227520170403
# nmdc:bsm-99-SCBI008M35526520170403
# nmdc:bsm-99-SCBI006M22020170424
# nmdc:bsm-99-SCBI067M35512520170719
# nmdc:bsm-99-SCBI006M73120170808
# nmdc:bsm-99-SCBI005M2153720171114
# nmdc:bsm-99-SCBI067M2839520171115
# nmdc:bsm-99-SCBI047M36510520180402
# nmdc:bsm-99-SCBI006M851520180402
# nmdc:bsm-99-SCBI004M2720180717
# nmdc:bsm-99-SCBI045M3722520181101
# nmdc:bsm-99-SCBI008M3453520181101
# nmdc:bsm-99-SCBI006M28820190401
# nmdc:bsm-99-SCBI045M45320190402
# nmdc:bsm-99-SCBI047M1320191022
# nmdc:bsm-99-SCBI045M173820191022
# nmdc:bsm-99-SCBI045M1253520191022
# nmdc:bsm-99-SCBI047M9533520200721
# nmdc:bsm-99-SCBI047M31521520200721
# nmdc:bsm-99-SCBI049M636520210720
# nmdc:bsm-99-SERC047M321320150325
# nmdc:bsm-99-SERC002O3317520150810
# nmdc:bsm-99-SERC005M351320150813
# nmdc:bsm-99-SERC046O3251520151117
# nmdc:bsm-99-SERC004M851120160407
# nmdc:bsm-99-SERC047O43220160407
# nmdc:bsm-99-SERC044O24531520160810
# nmdc:bsm-99-SERC002O8510520160812
# nmdc:bsm-99-SERC044O3057520161026
# nmdc:bsm-99-SERC044M13020170711
# nmdc:bsm-99-SERC003M3638520170711
# nmdc:bsm-99-SERC002M34220170712
# nmdc:bsm-99-SERC049M3728520171030
# nmdc:bsm-99-SERC007M3453020171031
# nmdc:bsm-99-SERC004M8526520180319
# nmdc:bsm-99-SERC002M2454520180320
# nmdc:bsm-99-SERC047M33220180711
# nmdc:bsm-99-SERC045M911520180712
# nmdc:bsm-99-SERC004M12720180712
# nmdc:bsm-99-SERC049M2053520181024
# nmdc:bsm-99-SERC049M1137520181024
# nmdc:bsm-99-SERC003M71720190319
# nmdc:bsm-99-SERC004M343620190319
# nmdc:bsm-99-SERC007M1153520190320
# nmdc:bsm-99-SERC002M1238520191028
# nmdc:bsm-99-SERC049M3535520191028
# nmdc:bsm-99-SERC0474120200323LOGISTICAL
# nmdc:bsm-99-SERC0024120200323LOGISTICAL
# nmdc:bsm-99-SERC044M372920201104
# nmdc:bsm-99-SERC047M1031520201104
# nmdc:bsm-99-SERC049M10420201104
# nmdc:bsm-99-SERC045M3517520210420
# nmdc:bsm-99-SERC007M1439520210420
# nmdc:bsm-99-SERC047M2653520210726
# nmdc:bsm-99-SERC007M756520210727
# nmdc:bsm-99-SERC002M23538520210707
# nmdc:bsm-99-SERC044M2951520210707
# nmdc:bsm-99-SERC045M32620210707
# nmdc:bsm-99-SERC005M155220211018
# nmdc:bsm-99-SERC007M3520211019
# nmdc:bsm-99-SERC044M2251520211019
# nmdc:bsm-99-SERC003M1053220211108
# nmdc:bsm-99-SERC004M45820211109
# nmdc:bsm-99-SERC001M3336520211109
# nmdc:bsm-99-SJER002M17720161101
# nmdc:bsm-99-SJER002M15620170314
# nmdc:bsm-99-SJER048M346520170314
# nmdc:bsm-99-SJER005M15720170510
# nmdc:bsm-99-SJER004M3652020170511
# nmdc:bsm-99-SJER001M37524520171030
# nmdc:bsm-99-SJER005M951220171031
# nmdc:bsm-99-SJER005M228520171031
# nmdc:bsm-99-SJER001M365020180220
# nmdc:bsm-99-SJER046M26820180222
# nmdc:bsm-99-SJER005M3458520180227
# nmdc:bsm-99-SJER004M37515520180227
# nmdc:bsm-99-SJER001M3515520181008
# nmdc:bsm-99-SJER003M213620190402
# nmdc:bsm-99-SJER001M3653520190401
# nmdc:bsm-99-SJER048M3053520190402
# nmdc:bsm-99-SJER025M750520190404
# nmdc:bsm-99-SJER046M145420190506
# nmdc:bsm-99-SJER046M20620190506
# nmdc:bsm-99-SJER005M35529520190508
# nmdc:bsm-99-SJER004M1853420190604
# nmdc:bsm-99-SJER003M336520191016
# nmdc:bsm-99-SJER048M2039520191016
# nmdc:bsm-99-SJER0012320200601LOGISTICAL
# nmdc:bsm-99-SJER0454120200601LOGISTICAL
# nmdc:bsm-99-SJER047M3753320201118
# nmdc:bsm-99-SJER005M25920210304
# nmdc:bsm-99-SJER048M1353420210518
# nmdc:bsm-99-SJER003M30120210519
# nmdc:bsm-99-SJER046M322420211026
# nmdc:bsm-99-SJER001M333420211026
# nmdc:bsm-99-SJER047M383120211108
# nmdc:bsm-99-SOAP005M3352120180618
# nmdc:bsm-99-SOAP045M382120180619
# nmdc:bsm-99-SOAP045M3452620181112
# nmdc:bsm-99-SOAP043M29539520181114
# nmdc:bsm-99-SOAP031M3053220190408
# nmdc:bsm-99-SOAP003M26320190528
# nmdc:bsm-99-SOAP0453920200315LOGISTICAL
# nmdc:bsm-99-SOAP025M183620200708
# nmdc:bsm-99-SOAP025M37420210615
# nmdc:bsm-99-SOAP006M1833520211111
# nmdc:bsm-99-SOAP0444120211113OTHER
# nmdc:bsm-99-SRER043M91520160614
# nmdc:bsm-99-SRER053M301420160721
# nmdc:bsm-99-SRER001M393920160721
# nmdc:bsm-99-SRER047M153520160721
# nmdc:bsm-99-SRER053M153420161021
# nmdc:bsm-99-SRER043M352120170612
# nmdc:bsm-99-SRER053M223720170612
# nmdc:bsm-99-SRER003M653620170612
# nmdc:bsm-99-SRER006M105620170815
# nmdc:bsm-99-SRER003M2456520170815
# nmdc:bsm-99-SRER053M130520171106
# nmdc:bsm-99-SRER053M14420171106
# nmdc:bsm-99-SRER001M1531520171106
# nmdc:bsm-99-SRER002M18320180605
# nmdc:bsm-99-SRER043M01620180801
# nmdc:bsm-99-SRER005M113620181114
# nmdc:bsm-99-SRER006M375920190604
# nmdc:bsm-99-SRER005M30720190806
# nmdc:bsm-99-SRER006M818520190806
# nmdc:bsm-99-SRER053M432520190806
# nmdc:bsm-99-SRER005M130520191029
# nmdc:bsm-99-SRER0032120200706LOGISTICAL
# nmdc:bsm-99-SRER0534120200706LOGISTICAL
# nmdc:bsm-99-SRER0042120200803LOGISTICAL
# nmdc:bsm-99-SRER0532120200803LOGISTICAL
# nmdc:bsm-99-SRER0024120200803LOGISTICAL
# nmdc:bsm-99-SRER0033920200803LOGISTICAL
# nmdc:bsm-99-SRER004M528520201028
# nmdc:bsm-99-SRER005M31529520210629
# nmdc:bsm-99-SRER002M3832520210719
# nmdc:bsm-99-SRER006M6513520210719
# nmdc:bsm-99-SRER047M115520210719
# nmdc:bsm-99-SRER006M1454520210830
# nmdc:bsm-99-SRER003M3526520210830
# nmdc:bsm-99-SRER002M3351920210830
# nmdc:bsm-99-SRER001M355820210810
# nmdc:bsm-99-SRER006M1952520211116
# nmdc:bsm-99-SRER005M151820211116
# nmdc:bsm-99-SRER052M155220211116
# nmdc:bsm-99-STEI001M87520160427
# nmdc:bsm-99-STEI001M30533520160427
# nmdc:bsm-99-STEI060M31538520160506
# nmdc:bsm-99-STEI004M0532520160721
# nmdc:bsm-99-STEI053M275920160721
# nmdc:bsm-99-STEI053M155020160721
# nmdc:bsm-99-STEI001M751020170419
# nmdc:bsm-99-STEI047M393720170420
# nmdc:bsm-99-STEI002M205220170508
# nmdc:bsm-99-STEI004M72220170508
# nmdc:bsm-99-STEI021M153520170508
# nmdc:bsm-99-STEI004M18536520170705
# nmdc:bsm-99-STEI021O30533520170705
# nmdc:bsm-99-STEI002M4524520170705
# nmdc:bsm-99-STEI003M553520171024
# nmdc:bsm-99-STEI004M34820171024
# nmdc:bsm-99-STEI008M33525520171024
# nmdc:bsm-99-STEI053M25820171025
# nmdc:bsm-99-STEI003M1753420180625
# nmdc:bsm-99-STEI004M1753220190430
# nmdc:bsm-99-STEI003O336520190619
# nmdc:bsm-99-STEI008M90520190619
# nmdc:bsm-99-STEI004M393720191001
# nmdc:bsm-99-STEI003M1138520191001
# nmdc:bsm-99-STEI059M215020191002
# nmdc:bsm-99-STEI0032120200416LOGISTICAL
# nmdc:bsm-99-STEI060M151020201013
# nmdc:bsm-99-STEI053M333220201013
# nmdc:bsm-99-STEI002M2430520201013
# nmdc:bsm-99-STEI060O398520210428
# nmdc:bsm-99-STEI060M61520210428
# nmdc:bsm-99-STEI001M36533520210625
# nmdc:bsm-99-STER016M92620130627
# nmdc:bsm-99-STER006M153720130822
# nmdc:bsm-99-STER005M31820131030
# nmdc:bsm-99-STER005M293420131030
# nmdc:bsm-99-STER003M383020131217
# nmdc:bsm-99-STER006M263920131217
# nmdc:bsm-99-STER006M20720131217
# nmdc:bsm-99-STER005M301820131217
# nmdc:bsm-99-STER005M183820140115
# nmdc:bsm-99-STER018M91120140618
# nmdc:bsm-99-STER033M233020140723
# nmdc:bsm-99-STER035M22720140723
# nmdc:bsm-99-STER006M303720140820
# nmdc:bsm-99-STER006M15120140917
# nmdc:bsm-99-STER032M014520160421
# nmdc:bsm-99-STER027M8513520160817
# nmdc:bsm-99-STER026M6535520170410
# nmdc:bsm-99-STER027M3953420170501
# nmdc:bsm-99-STER031M380520170626
# nmdc:bsm-99-STER031M436520170605
# nmdc:bsm-99-STER029M05520170605
# nmdc:bsm-99-STER011M30518520170606
# nmdc:bsm-99-STER029M1453820171113
# nmdc:bsm-99-STER006M223320180423
# nmdc:bsm-99-STER028M33517520180718
# nmdc:bsm-99-STER028M1135520180718
# nmdc:bsm-99-STER027M7536520180719
# nmdc:bsm-99-STER026M356520181017
# nmdc:bsm-99-STER006M3053820181022
# nmdc:bsm-99-STER031M2132520190422
# nmdc:bsm-99-STER028M1837520190423
# nmdc:bsm-99-STER027M28534520190716
# nmdc:bsm-99-STER006M45520191021
# nmdc:bsm-99-STER0064120200420LOGISTICAL
# nmdc:bsm-99-STER0122120200420LOGISTICAL
# nmdc:bsm-99-STER0124120200420LOGISTICAL
# nmdc:bsm-99-STER0272320200420LOGISTICAL
# nmdc:bsm-99-STER016M2035520201020
# nmdc:bsm-99-STER011M4520201020
# nmdc:bsm-99-STER026M51520201020
# nmdc:bsm-99-STER027M38535520201021
# nmdc:bsm-99-STER016M39536520210426
# nmdc:bsm-99-STER006M9532520210609
# nmdc:bsm-99-STER0313920210610LOGISTICAL
# nmdc:bsm-99-STER0262320210610LOGISTICAL
# nmdc:bsm-99-STER011M1537520211018
# nmdc:bsm-99-TALL004M17920140516
# nmdc:bsm-99-TALL002M12720140516
# nmdc:bsm-99-TALL004M344020140903
# nmdc:bsm-99-TALL006M143020140903
# nmdc:bsm-99-TALL004M392220141027
# nmdc:bsm-99-TALL002O363520141027
# nmdc:bsm-99-TALL001M163020141027
# nmdc:bsm-99-TALL054M332520160823
# nmdc:bsm-99-TALL001M251520160823
# nmdc:bsm-99-TALL054M920520161024
# nmdc:bsm-99-TALL051M3013520170404
# nmdc:bsm-99-TALL054M121520170404
# nmdc:bsm-99-TALL002M83420170424
# nmdc:bsm-99-TALL001O16539520170424
# nmdc:bsm-99-TALL006M236520170406
# nmdc:bsm-99-TALL003M3313520170406
# nmdc:bsm-99-TALL004M4513520170406
# nmdc:bsm-99-TALL003M205220170612
# nmdc:bsm-99-TALL051M1959520170614
# nmdc:bsm-99-TALL047M9020170626
# nmdc:bsm-99-TALL051M25720171101
# nmdc:bsm-99-TALL051M25720171127
# nmdc:bsm-99-TALL002M263120171127
# nmdc:bsm-99-TALL001M31520180620
# nmdc:bsm-99-TALL006M29531520181031
# nmdc:bsm-99-TALL044M2753520190327
# nmdc:bsm-99-TALL047M305920190617
# nmdc:bsm-99-TALL054M851520191106
# nmdc:bsm-99-TALL001M3751420191107
# nmdc:bsm-99-TALL0014120200406LOGISTICAL
# nmdc:bsm-99-TALL0073920200406LOGISTICAL
# nmdc:bsm-99-TALL0032320200406LOGISTICAL
# nmdc:bsm-99-TALL054M18020200707
# nmdc:bsm-99-TALL004M1253620210421
# nmdc:bsm-99-TALL004M30420210421
# nmdc:bsm-99-TALL044M35920210426
# nmdc:bsm-99-TALL044M245920210426
# nmdc:bsm-99-TALL047M6513520211101
# nmdc:bsm-99-TALL044M6511520211101
# nmdc:bsm-99-TALL003M5518520211103
# nmdc:bsm-99-TEAK002M3139520190624
# nmdc:bsm-99-TEAK004M12531520190723
# nmdc:bsm-99-TEAK003M373620191022
# nmdc:bsm-99-TEAK0022120200511LOGISTICAL
# nmdc:bsm-99-TEAK005M724520201103
# nmdc:bsm-99-TEAK005M3826520201103
# nmdc:bsm-99-TEAK0464120201105LOGISTICAL
# nmdc:bsm-99-TEAK045M71920210524
# nmdc:bsm-99-TEAK0052320210510LOGISTICAL
# nmdc:bsm-99-TEAK004O617520210601
# nmdc:bsm-99-TEAK001M253320210720
# nmdc:bsm-99-TEAK045M1433520210810
# nmdc:bsm-99-TEAK046M352120210824
# nmdc:bsm-99-TEAK043M253720211027
# nmdc:bsm-99-TEAK001M952120211011
# nmdc:bsm-99-TEAK0032120211019LOCATIONSNOWCOVERED
# nmdc:bsm-99-TEAK0462120211019LOCATIONSNOWCOVERED
# nmdc:bsm-99-TEAK001M3832520211103
# nmdc:bsm-99-TEAK004M5532520211103
# nmdc:bsm-99-TOOL043O3252720170719
# nmdc:bsm-99-TOOL001M245020170721
# nmdc:bsm-99-TOOL001O71820170818
# nmdc:bsm-99-TOOL004O1553520190807
# nmdc:bsm-99-TOOL0023920200803OTHER
# nmdc:bsm-99-TREE006M1554520150722
# nmdc:bsm-99-TREE006M3836520160429
# nmdc:bsm-99-TREE041M3118520160506
# nmdc:bsm-99-TREE001O393720160718
# nmdc:bsm-99-TREE007M1753720160719
# nmdc:bsm-99-TREE041M3720160719
# nmdc:bsm-99-TREE046M8534520161025
# nmdc:bsm-99-TREE007M3720161025
# nmdc:bsm-99-TREE003O3318520170417
# nmdc:bsm-99-TREE041M851820171018
# nmdc:bsm-99-TREE006M84520180510
# nmdc:bsm-99-TREE046M35520520180626
# nmdc:bsm-99-TREE041M1538520180626
# nmdc:bsm-99-TREE004O3252720181002
# nmdc:bsm-99-TREE049M105420190501
# nmdc:bsm-99-TREE001M4534520190502
# nmdc:bsm-99-TREE003M347520190502
# nmdc:bsm-99-TREE004O9820191017
# nmdc:bsm-99-TREE0462120200428LOGISTICAL
# nmdc:bsm-99-TREE046M22020200727
# nmdc:bsm-99-TREE050M3726520200727
# nmdc:bsm-99-TREE003M3520520200708
# nmdc:bsm-99-TREE002O455520201006
# nmdc:bsm-99-TREE006M3251920201027
# nmdc:bsm-99-TREE014M145420201028
# nmdc:bsm-99-TREE041M451920210419
# nmdc:bsm-99-TREE006M7620210420
# nmdc:bsm-99-TREE002O251520210622
# nmdc:bsm-99-TREE041M3317520210629
# nmdc:bsm-99-TREE002O3638520211006
# nmdc:bsm-99-UKFS044M3352320150825
# nmdc:bsm-99-UKFS003M388520160420
# nmdc:bsm-99-UKFS003M34529520160420
# nmdc:bsm-99-UKFS003M62720160420
# nmdc:bsm-99-UKFS043M2456520160422
# nmdc:bsm-99-UKFS001M195620160422
# nmdc:bsm-99-UKFS001M2453120160422
# nmdc:bsm-99-UKFS009M308520160719
# nmdc:bsm-99-UKFS003M23920161031
# nmdc:bsm-99-UKFS032M165420170802
# nmdc:bsm-99-UKFS002M36920171030
# nmdc:bsm-99-UKFS032M3758520171030
# nmdc:bsm-99-UKFS043M173920180321
# nmdc:bsm-99-UKFS032M2750520180409
# nmdc:bsm-99-UKFS031M72720180813
# nmdc:bsm-99-UKFS031M72720180827
# nmdc:bsm-99-UKFS003M205520180814
# nmdc:bsm-99-UKFS004M212520180815
# nmdc:bsm-99-UKFS002M180520180829
# nmdc:bsm-99-UKFS032M34528520181030
# nmdc:bsm-99-UKFS003M312420181030
# nmdc:bsm-99-UKFS001M315220181127
# nmdc:bsm-99-UKFS032M34528520181127
# nmdc:bsm-99-UKFS043M052820190326
# nmdc:bsm-99-UKFS002M2536520191023
# nmdc:bsm-99-UKFS0443920200330LOGISTICAL
# nmdc:bsm-99-UKFS031M145420200803
# nmdc:bsm-99-UKFS002M236520200804
# nmdc:bsm-99-UKFS002M852920201027
# nmdc:bsm-99-UKFS031M1553620210329
# nmdc:bsm-99-UKFS003M1954520210726
# nmdc:bsm-99-UKFS009M32220211102
# nmdc:bsm-99-UKFS009M19620211102
# nmdc:bsm-99-UKFS009M3251020211102
# nmdc:bsm-99-UNDE017M153320140520
# nmdc:bsm-99-UNDE008M33020140609
# nmdc:bsm-99-UNDE017O213820140610
# nmdc:bsm-99-UNDE017M213820140610
# nmdc:bsm-99-UNDE006M103420140707
# nmdc:bsm-99-UNDE013M2020140708
# nmdc:bsm-99-UNDE007M33220140710
# nmdc:bsm-99-UNDE037O251720140710
# nmdc:bsm-99-UNDE013M95320160504
# nmdc:bsm-99-UNDE019M251620160505
# nmdc:bsm-99-UNDE014M22120160518
# nmdc:bsm-99-UNDE038O156520160524
# nmdc:bsm-99-UNDE038M323620160524
# nmdc:bsm-99-UNDE019M164520160728
# nmdc:bsm-99-UNDE043M719520160815
# nmdc:bsm-99-UNDE017M3331520161017
# nmdc:bsm-99-UNDE008M3352220161017
# nmdc:bsm-99-UNDE044M431520161018
# nmdc:bsm-99-UNDE044O382520161018
# nmdc:bsm-99-UNDE007M132520161018
# nmdc:bsm-99-UNDE003O2553520170511
# nmdc:bsm-99-UNDE044M017520170512
# nmdc:bsm-99-UNDE037O37514520170512
# nmdc:bsm-99-UNDE002O41920170802
# nmdc:bsm-99-UNDE010O65520170802
# nmdc:bsm-99-UNDE010M213320170802
# nmdc:bsm-99-UNDE002O25920171010
# nmdc:bsm-99-UNDE038O12520180521
# nmdc:bsm-99-UNDE001M958520180723
# nmdc:bsm-99-UNDE038O31528520190603
# nmdc:bsm-99-UNDE037M35530520190805
# nmdc:bsm-99-UNDE001M95520190916
# nmdc:bsm-99-UNDE044O3653520190916
# nmdc:bsm-99-UNDE038O257520190916
# nmdc:bsm-99-UNDE001M209520191007
# nmdc:bsm-99-UNDE037O12520191009
# nmdc:bsm-99-UNDE0084120200511LOGISTICAL
# nmdc:bsm-99-UNDE0012120200511LOGISTICAL
# nmdc:bsm-99-UNDE001M321720200804
# nmdc:bsm-99-UNDE006M1033520200930
# nmdc:bsm-99-UNDE002O4518520201001
# nmdc:bsm-99-UNDE037O22820210511
# nmdc:bsm-99-UNDE003O2233520210920
# nmdc:bsm-99-UNDE010O137520210920
# nmdc:bsm-99-WOOD003M23320140507
# nmdc:bsm-99-WOOD001M30520140605
# nmdc:bsm-99-WOOD004M4920140828
# nmdc:bsm-99-WOOD004M2753520160414
# nmdc:bsm-99-WOOD004M3058520160713
# nmdc:bsm-99-WOOD042M125020160713
# nmdc:bsm-99-WOOD045M255120161020
# nmdc:bsm-99-WOOD042M24320161020
# nmdc:bsm-99-WOOD044M301820161020
# nmdc:bsm-99-WOOD002M185920170509
# nmdc:bsm-99-WOOD003M1734520170712
# nmdc:bsm-99-WOOD045O224520180507
# nmdc:bsm-99-WOOD044M255520180508
# nmdc:bsm-99-WOOD003O2953120180509
# nmdc:bsm-99-WOOD005M2853620180724
# nmdc:bsm-99-WOOD001M35511520180927
# nmdc:bsm-99-WOOD004M11533520180927
# nmdc:bsm-99-WOOD005M3253720181002
# nmdc:bsm-99-WOOD044M392020190514
# nmdc:bsm-99-WOOD001M311120190716
# nmdc:bsm-99-WOOD003M23220190717
# nmdc:bsm-99-WOOD042M1255520191023
# nmdc:bsm-99-WOOD042M2153520191023
# nmdc:bsm-99-WOOD0044120200518LOGISTICAL
# nmdc:bsm-99-WOOD0024120200518LOGISTICAL
# nmdc:bsm-99-WOOD0034120201012LOGISTICAL
# nmdc:bsm-99-WOOD0454120201012LOGISTICAL
# nmdc:bsm-99-WOOD045M3758520210503
# nmdc:bsm-99-WOOD045M353220210527
# nmdc:bsm-99-WOOD042M653320210503
# nmdc:bsm-99-WOOD043M914520210503
# nmdc:bsm-99-WOOD002M31420210531
# nmdc:bsm-99-WOOD003M217520210531
# nmdc:bsm-99-WOOD024M341320210531
# nmdc:bsm-99-WOOD043M3052220210712
# nmdc:bsm-99-WOOD004M275720210714
# nmdc:bsm-99-WOOD024M92120210728
# nmdc:bsm-99-WOOD024M25720210714
# nmdc:bsm-99-WOOD004M653020211004
# nmdc:bsm-99-WOOD002M08520211026
# nmdc:bsm-99-WOOD045M255520211006
# nmdc:bsm-99-WOOD024M23538520211102
# nmdc:bsm-99-WREF003O4533520180509
# nmdc:bsm-99-WREF001M36532520180625
# nmdc:bsm-99-WREF070M3152320180628
# nmdc:bsm-99-WREF008M2153820181002
# nmdc:bsm-99-WREF073O19320181004
# nmdc:bsm-99-WREF073M3914520190430
# nmdc:bsm-99-WREF072O151920190521
# nmdc:bsm-99-WREF072M151920190521
# nmdc:bsm-99-WREF007M452920190522
# nmdc:bsm-99-WREF001O118520190522
# nmdc:bsm-99-WREF003M3253420190502
# nmdc:bsm-99-WREF005M245220190619
# nmdc:bsm-99-WREF003M24720190620
# nmdc:bsm-99-WREF072O20536520190708
# nmdc:bsm-99-WREF073O2130520191031
# nmdc:bsm-99-WREF073M1653920191031
# nmdc:bsm-99-WREF0054120200427LOGISTICAL
# nmdc:bsm-99-WREF071M02520200715
# nmdc:bsm-99-WREF007M292520200722
# nmdc:bsm-99-WREF008M395120201012
# nmdc:bsm-99-WREF008M29720210621
# nmdc:bsm-99-WREF007O3721520211006
# nmdc:bsm-99-YELL003M555520180710
# nmdc:bsm-99-YELL046M371920180712
# nmdc:bsm-99-YELL048M3517520180712
# nmdc:bsm-99-YELL009M3352120180712
# nmdc:bsm-99-YELL001M3853720180910
# nmdc:bsm-99-YELL012M3259520180910
# nmdc:bsm-99-YELL009M3253820180911
# nmdc:bsm-99-YELL016M3229520180913
# nmdc:bsm-99-YELL003M38533520190821
# nmdc:bsm-99-YELL052M553820191002
# nmdc:bsm-99-YELL0484120200504LOGISTICAL
# nmdc:bsm-99-YELL0092320200504LOGISTICAL
# nmdc:bsm-99-YELL0522120200504LOGISTICAL
# nmdc:bsm-99-YELL003M228520200730
# nmdc:bsm-99-YELL016M937520200710
# nmdc:bsm-99-YELL016M25320200710
# nmdc:bsm-99-YELL009M727520200915
# nmdc:bsm-99-YELL012M63920200916
# nmdc:bsm-99-YELL052M9526520200922
# nmdc:bsm-99-YELL048M3451320200924
# nmdc:bsm-99-YELL009M3555520201006
# nmdc:bsm-99-YELL016M1553820201008
# nmdc:bsm-99-YELL009M3124520210517
# nmdc:bsm-99-YELL0464120210520MANAGEMENT
# nmdc:bsm-99-YELL009M3231520210706
# nmdc:bsm-99-YELL009M3931520210920

# %%
locations_as_frs = domains + sites + named_locations
database = {
    "field_research_site_set": locations_as_frs,
    "biosample_set": biosamples,
}

yaml_dumper.dump(database, "../local/neon_in_nmdc.yaml")

# %%
# todo add linkml validation and jsonschema validation
