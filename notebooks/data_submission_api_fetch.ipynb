# %%
import pprint

import requests

# %%
# still have to get this from a logged-in browser session
# https://data-dev.microbiomedata.org/ for now 2024-06-26
# FF dev console -> storage -> local storage -> storage.refreshToken
# should probably put this in a .env file

data_portal_refresh_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIyZjRkYjczNS00MTJkLTQ2YjQtYjhlMS0yNGUwMjQ4ZjJmNmYiLCJ0eXAiOiJSZWZyZXNoIiwiaXNzIjoiaHR0cHM6Ly9kYXRhLWRldi5taWNyb2Jpb21lZGF0YS5vcmcvIiwiaWF0IjoxNzE4NzM2ODg4LCJleHAiOjE3NTAyNzI4ODh9.RL5dxGe8SPr3HqoC0-0WfVjtM0Yr3H2IzUwJSmShhZs"

auth_response = requests.post(
            "https://data-dev.microbiomedata.org/auth/refresh",
            json={"refresh_token": data_portal_refresh_token},
        ).json()

access_token = auth_response["access_token"]

# now setting up headers for next request
# what is the persistence for this bearer token (FROM THE BROWSER   STORAGE)?
# ACCESS toke may be refreshed ever ~ 24 hours
headers = {"content-type": "application/json; charset=UTF-8",'Authorization':'Bearer {}'.format(access_token)}
pprint.pprint(headers)

# BTW what is a bearer token?
# may be related to oauth 

# response: Dict[str, Any] = requests.get(f"https://data-dev.microbiomedata.org/api/metadata_submission/{metadata_submission_id}",
#             headers=headers,
#         ).json()
# Out:
# {'Authorization': 'Bearer '
#                   'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIyZjRkYjczNS00MTJkLTQ2YjQtYjhlMS0yNGUwMjQ4ZjJmNmYiLCJ0eXAiOiJCZWFyZXIiLCJpc3MiOiJodHRwczovL2RhdGEtZGV2Lm1pY3JvYmlvbWVkYXRhLm9yZy8iLCJpYXQiOjE3MjAwMzA0NzcsImV4cCI6MTcyMDExNjg3N30.2nih8ZSbQM2m3ZphCJ6lJSIAD-Oq_b-JqpKuRykySyA',
#  'content-type': 'application/json; charset=UTF-8'}

# %%
# try metadata_submission
# has offset and limit parameters
response = requests.get(
    "https://data-dev.microbiomedata.org/api/metadata_submission",
    params={"offset": 3, "limit": 3},
    headers=headers,
).json()

# %%
pprint.pprint(response)
# Out:
# {'count': 269,
#  'results': [{'author': {'id': 'ff3b7782-96e6-4397-9c7d-df2bcb01a6c4',
#                          'is_admin': True,
#                          'name': 'Montana Smith',
#                          'orcid': '0000-0002-8683-0050'},
#               'author_orcid': '0000-0002-8683-0050',
#               'created': '2024-06-25T16:40:57.079965',
#               'id': '3ed2fe5d-89bc-4152-9bb0-1b09d2aeae93',
#               'lock_updated': '2024-06-25T16:41:08.535381',
#               'locked_by': {'id': 'ff3b7782-96e6-4397-9c7d-df2bcb01a6c4',
#                             'is_admin': True,
#                             'name': 'Montana Smith',
#                             'orcid': '0000-0002-8683-0050'},
#               'metadata_submission': {'addressForm': {'biosafetyLevel': '',
#                                                       'comments': '',
#                                                       'description': '',
# ...

# %%
print(response.keys())
# Out:
# dict_keys(['count', 'results'])

# %%
print(response['results'][0].keys())
# Out:
# dict_keys(['metadata_submission', 'status', 'id', 'author_orcid', 'created', 'author', 'lock_updated', 'locked_by', 'permission_level'])

# %%
print(response['results'][0]['metadata_submission'].keys())
# Out:
# dict_keys(['packageName', 'contextForm', 'addressForm', 'templates', 'studyForm', 'multiOmicsForm', 'sampleData'])

# %%
print(response['results'][0]['metadata_submission']['sampleData'].keys())
# Out:
# dict_keys([])

# %%
# print(response['results'][0]['metadata_submission']['sampleData']['soil_data'][0].keys())

# %%
print(response['results'][0]['metadata_submission']['packageName'])
# Out:
# soil
